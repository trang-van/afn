# %% [markdown]
# Sources: https://stackoverflow.com/questions/6400416/figure-out-if-a-business-name-is-very-similar-to-another-one-python

# %%
import pandas as pd
import re
import os
from os.path import dirname, abspath
from IPython.display import display, HTML # Source: https://stackoverflow.com/questions/38783027/jupyter-notebook-display-two-pandas-tables-side-by-side

# %%
# Get Current Working Directory and Parent Path (for reading files in different folders)
## Source: https://stackoverflow.com/questions/30218802/get-parent-of-current-directory-from-python-script/30218825
d = dirname(dirname(abspath(os.getcwd())))
d
# Out:
# 'C:\\Users\\Trang\\Desktop\\afn'

# %% [markdown]
# ## Load Orbis Data & PPP Loan Data (Filtered)
#
# Explore different cases of business names.

# %%
orbis_file = d+'/ppp-loan-data/Orbis database_six cities only.csv'
ppp_file = d+'/ppp-loan-data/out/bay_bus_from_ppp_minority.csv'

# %%
orbis_df = pd.read_csv(orbis_file)
orbis_df.head()
# Out:
#      Company name Latin alphabet Inactive Quoted Branch OwnData Woco  \
# 0  CALIFORNIA NURSES ASSOCIATION       No     No    Yes      No   No
# 1           HONDA CARS OF CORONA       No     No     No      No   No
# 2           SIMI MANAGEMENT CORP       No     No     No      No   No
# 3   ECONOMY LUMBER CO OF OAKLAND       No     No     No      No   No
# 4                  BROADWAY FORD       No     No     No      No   No
#
#   Country ISO code  NACE Rev. 2, core code (4 digits) Consolidation code  \
# 0               US                               9412                 LF
# 1               US                               4519                 LF
# 2               US                               4519                 LF
# 3               US                               4778                 LF
# 4               US                               4519                 LF
#
#    Last avail. year  ...         Latitude         Longitude  \
# 0            2019.0  ...  37° 48' 30.9" N   122° 16' 1.2" W
# 1            2019.0  ...  37° 49' 18.2" N  122° 15' 37.2" W
# 2            2019.0  ...   37° 49' 0.2" N  122° 15' 48.6" W
# 3            2019.0  ...   37° 46' 7.3" N  122° 13' 10.9" W
# 4            2008.0  ...  37° 48' 51.1" N  122° 15' 53.5" W
#
#                Website address NAICS 2017, core code (4 digits)  \
# 0  www.calnursesfoundation.org                             8139
# 1    www.hondacarsofcorona.com                             4411
# 2                          NaN                             4411
# 3      www.economylumberco.com                             4441
# 4       www.mybroadwayford.com                             4411
#
#                  NAICS 2017, core code - description Size classification  \
# 0  Business, Professional, Labor, Political, and ...  Very large company
# 1                                 Automobile Dealers       Large company
# 2                                 Automobile Dealers       Large company
# 3             Building Material and Supplies Dealers       Large company
# 4                                 Automobile Dealers       Large company
#
#   Type of entity Ethnic minority owned indicator (in US)  \
# 0      Corporate                                      No
# 1      Corporate                                      No
# 2      Corporate                                      No
# 3      Corporate                                      No
# 4      Corporate                                      No
#
#   Woman owned indicator (in US) Study Area
# 0                            No    Oakland
# 1                            No    Oakland
# 2                            No    Oakland
# 3                            No    Oakland
# 4                            No    Oakland
#
# [5 rows x 27 columns]

# %%
orbis_df.columns
# Out:
# Index(['Company name Latin alphabet', 'Inactive', 'Quoted', 'Branch',
#        'OwnData', 'Woco', 'Country ISO code',
#        'NACE Rev. 2, core code (4 digits)', 'Consolidation code',
#        'Last avail. year',
#        'Operating revenue (Turnover)\nth USD Last avail. yr',
#        'Number of employees\nLast avail. yr', 'Address line 1\nLatin Alphabet',
#        'Address line 2\nLatin Alphabet', 'Postcode\nLatin Alphabet',
#        'City\nLatin Alphabet', 'Region in country', 'Latitude', 'Longitude',
#        'Website address', 'NAICS 2017, core code (4 digits)',
#        'NAICS 2017, core code - description', 'Size classification',
#        'Type of entity', 'Ethnic minority owned indicator (in US)',
#        'Woman owned indicator (in US)', 'Study Area'],
#       dtype='object')

# %%
ppp_df = pd.read_csv(ppp_file)
ppp_df.head(50)
# Out:
#     LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0   5224738402   02/08/2021          912.0              PPS
# 1   5359188509   02/27/2021          912.0              PPS
# 2   5554978603   03/20/2021          912.0              PPS
# 3   9634738305   01/31/2021          912.0              PPS
# 4   5004708402   02/07/2021          912.0              PPS
# 5   5893177303   04/30/2020          912.0              PPP
# 6   7220037301   04/30/2020          912.0              PPP
# 7   5147588302   01/25/2021          912.0              PPS
# 8   3404988405   02/04/2021          912.0              PPS
# 9   6070528704   04/03/2021          912.0              PPS
# 10  6408068401   02/10/2021          912.0              PPS
# 11  2347158510   02/20/2021          912.0              PPS
# 12  8840818410   02/14/2021          912.0              PPS
# 13  6891887904   06/16/2020          912.0              PPP
# 14  2200868310   01/20/2021          912.0              PPS
# 15  7788707108   04/14/2020          912.0              PPP
# 16  2517877304   04/29/2020          912.0              PPP
# 17  2119548507   02/19/2021          912.0              PPS
# 18  5998657704   05/01/2020          912.0              PPP
# 19  2605238710   03/30/2021          912.0              PPP
# 20  7727278309   01/28/2021          912.0              PPS
# 21  2496407706   05/01/2020          912.0              PPP
# 22  5567127707   05/01/2020          912.0              PPP
# 23  2281948605   03/13/2021          912.0              PPS
# 24  5785248310   01/25/2021          912.0              PPS
# 25  3745407103   04/12/2020          912.0              PPP
# 26  6685727803   06/02/2020          912.0              PPP
# 27  6336148401   02/10/2021          912.0              PPS
# 28  3670108805   04/15/2021          912.0              PPS
# 29  8493767003   04/08/2020          912.0              PPP
# 30  5437248303   01/25/2021          912.0              PPS
# 31  2111568508   02/19/2021          912.0              PPS
# 32  4297288601   03/18/2021          912.0              PPS
# 33  7643497301   04/30/2020          912.0              PPP
# 34  8539448407   02/13/2021          912.0              PPS
# 35  8711708601   03/25/2021          912.0              PPS
# 36  2317618407   02/03/2021          912.0              PPS
# 37  5292847700   05/01/2020          912.0              PPP
# 38  7078558309   01/27/2021          912.0              PPS
# 39  3482517109   04/11/2020          912.0              PPP
# 40  4681108304   01/23/2021          912.0              PPS
# 41  6774047704   05/01/2020          912.0              PPP
# 42  4711548603   03/18/2021          912.0              PPS
# 43  3298888307   01/21/2021          912.0              PPS
# 44  6633688700   04/04/2021          912.0              PPS
# 45  2567047703   05/01/2020          912.0              PPP
# 46  7526958305   01/28/2021          912.0              PPS
# 47  2621627310   04/29/2020          912.0              PPP
# 48  2700357201   04/16/2020          912.0              PPP
# 49  2199528402   02/03/2021          912.0              PPS
#
#                                 BorrowerName  \
# 0                                     ICHINA
# 1                        BANZAI IZAKAYA INC.
# 2                    RANGOON SUPER STARS LLC
# 3                           JBR PARTNERS INC
# 4                                  OSAKE INC
# 5                          BAINS ENTERPRISES
# 6                REN LEI CONSTRUCTION CO INC
# 7                         KVS PRODUCTION INC
# 8                        RED CHILI GROUP INC
# 9                                SPARX 7 LLC
# 10                        PRESTIGE FOODS INC
# 11                       BLUE SKY FOODS INC.
# 12                   TECHLAND ASSOCIATES INC
# 13                       LYC RESTAURANT INC.
# 14                        OPLS LOS ALTOS LLC
# 15                     WEST COUNTY OPTOMETRY
# 16                     PENINSULA WEALTH, LLC
# 17       CLASSIC COLLISION REPAIR CENTER INC
# 18       CLASSIC COLLISION REPAIR CENTER INC
# 19                           INTI ENERGY LLC
# 20                           SPOTLITE CM LLC
# 21                 SPIRE MANUFACTURING, INC.
# 22                           YOUNG EUI JEONG
# 23      SPECTRUM PAINTING AND DECORATING INC
# 24                   THE ROCKRIDGE CAFE INC.
# 25           SAMURAI JAPANESE RESTAURANT INC
# 26                RISTORANTE BUON GUSTO, INC
# 27                           INDELICATO INC.
# 28                        TITAN BACKFLOW LLC
# 29                              4C AIR, INC.
# 30                 DG AUTO BODY & PAINT INC.
# 31                           COCONUT BAY INC
# 32                    HON'S CONSTRUCTION INC
# 33                          JUEI KAO DMD INC
# 34  FACES SF (FAMILY & CHILD EMPOWERMENT SER
# 35                               ONEMOB INC.
# 36                     CHAOJU INVESTMENT LLC
# 37                      CELERIUS GROUP, INC.
# 38                       CELERIUS GROUP INC.
# 39           G SPORTS PHYSICAL THERAPY, INC.
# 40                     IVY TRUMAN AUTOMOTIVE
# 41                     IVY TRUMAN AUTOMOTIVE
# 42                             EDGEWORX INC.
# 43                        EJB INVESTMENT INC
# 44                             TURQUOISE LLC
# 45                PRAKASH ADVANI D.D.S. INC.
# 46                       GARCIA & GURNEY ALC
# 47                   BEATRIZ AND PADILLA INC
# 48                 MARY PAULINE PUNO DDS INC
# 49                     CAMBRIAN ACADEMY INC.
#
#                      BorrowerAddress         BorrowerCity BorrowerState  \
# 0                       70 Valley Ct             Atherton            CA
# 1                    1633 Bonanza St         Walnut Creek            CA
# 2                      542 Freya Way        Pleasant Hill            CA
# 3                     1333 Evans Ave        San Francisco            CA
# 4                      2446 Patio Ct           Santa Rosa            CA
# 5   4160 suisun valley rd suite E655            fairfield            CA
# 6                      750 LAWTON ST        SAN FRANCISCO            CA
# 7             601 Mission Bay Blvd N        San Francisco            CA
# 8                 29583 Mission Blvd              Hayward            CA
# 9                    333 Potrero Ave        San Francisco            CA
# 10                 15900 Monterey St          Morgan Hill            CA
# 11                2300 Polvorosa Ave          San Leandro            CA
# 12                   2786 Bayview Dr              Fremont            CA
# 13                    1540 Ocean Ave        San Francisco            CA
# 14        3130 Alpine Rd Ste 288-141       Portola Valley            CA
# 15               11780 SAN PABLO AVE           EL CERRITO            CA
# 16    350 Townsend Street, Suite 411        San Francisco            CA
# 17                      555 Irwin St           San Rafael            CA
# 18                      555 IRWIN ST           SAN RAFAEL            CA
# 19       7550 St Patrick Way Apt 434               Dublin            CA
# 20                  645 Broderick St        San Francisco            CA
# 21                  49016 MILMONT DR              FREMONT            CA
# 22                       2180 3RD ST            LIVERMORE            CA
# 23           1325 Howard Ave PMB 336           Burlingame            CA
# 24                  5492 College Ave              Oakland            CA
# 25                5007 Lone Tree Way              Antioch            CA
# 26                  224 Grand Avenue  South San Francisco            CA
# 27                   5546 Geary Blvd        San Francisco            CA
# 28                 904 Dartmouth Way              Concord            CA
# 29                    1147 TASMAN DR            SUNNYVALE            CA
# 30              44201 S Grimmer Blvd              Fremont            CA
# 31                   1107 Howard Ave           Burlingame            CA
# 32                      519 Green St        San Francisco            CA
# 33        7455 EL CAMINO REAL, STE K            Daly City            CA
# 34                  1101 Masonic Ave        San Francisco            CA
# 35                2013 Elderberry Dr            San Ramon            CA
# 36              413 E El Camino Real            Sunnyvale            CA
# 37               3 E 3RD AVE STE 200            SAN MATEO            CA
# 38           1049 El Monte Ave Ste C        Mountain View            CA
# 39                        PO Box 558        San Francisco            CA
# 40        1062 E EL CAMINO REAL ABCD            SUNNYVALE            CA
# 41     1062 E EL CAMINO REAL A,B,C,D            SUNNYVALE            CA
# 42                2933 Hillegass Ave             Berkeley            CA
# 43                  785 Oak Grove Rd              Concord            CA
# 44                     535 Bryant St            Palo Alto            CA
# 45          14414 Saddle Mountain Dr            Los Altos            CA
# 46     6700 Koll Center Pkwy Ste 330           Pleasanton            CA
# 47                7384 Commerce Blvd               COTATI            CA
# 48  1 EMBARCADERO CENTER LOBBY LEVEL        SAN FRANCISCO            CA
# 49                 4340 Almaden Expy             San Jose            CA
#
#    BorrowerZip LoanStatusDate  ...        Gender      Veteran  NonProfit  \
# 0   94027-6472            NaN  ...  Female Owned  Non-Veteran        NaN
# 1   94596-4525            NaN  ...    Male Owned  Non-Veteran        NaN
# 2   94523-1712            NaN  ...    Male Owned  Non-Veteran        NaN
# 3   94124-1705            NaN  ...    Male Owned  Non-Veteran        NaN
# 4   95405-6737            NaN  ...  Female Owned  Non-Veteran        NaN
# 5        94534            NaN  ...    Male Owned   Unanswered        NaN
# 6        94122            NaN  ...    Male Owned   Unanswered        NaN
# 7   94158-2472            NaN  ...    Male Owned      Veteran        NaN
# 8   94544-6129            NaN  ...    Male Owned   Unanswered        NaN
# 9   94103-4816     04/03/2021  ...    Male Owned   Unanswered        NaN
# 10  95037-5444            NaN  ...  Female Owned  Non-Veteran        NaN
# 11  94577-2218            NaN  ...  Female Owned  Non-Veteran        NaN
# 12  94538-6518            NaN  ...    Male Owned  Non-Veteran        NaN
# 13  94112-1716            NaN  ...    Male Owned  Non-Veteran        NaN
# 14  94028-7549            NaN  ...    Male Owned  Non-Veteran        NaN
# 15       94530     04/20/2021  ...    Male Owned  Non-Veteran        NaN
# 16  94107-1693            NaN  ...    Unanswered   Unanswered        NaN
# 17  94901-3914            NaN  ...    Male Owned  Non-Veteran        NaN
# 18  94901-3914     04/16/2021  ...    Male Owned  Non-Veteran        NaN
# 19  94568-4883            NaN  ...    Male Owned  Non-Veteran        NaN
# 20  94117-1411            NaN  ...    Male Owned   Unanswered        NaN
# 21       94538     03/20/2021  ...  Female Owned  Non-Veteran        NaN
# 22  94550-4529            NaN  ...    Male Owned  Non-Veteran        NaN
# 23  94010-4212            NaN  ...    Male Owned  Non-Veteran        NaN
# 24  94618-1552            NaN  ...  Female Owned  Non-Veteran        NaN
# 25  94531-8690     03/19/2021  ...    Male Owned  Non-Veteran        NaN
# 26       94080     04/29/2021  ...    Male Owned  Non-Veteran        NaN
# 27  94121-2209            NaN  ...    Unanswered   Unanswered        NaN
# 28  94518-3820            NaN  ...    Male Owned  Non-Veteran        NaN
# 29  94089-2228     12/17/2020  ...    Male Owned  Non-Veteran        NaN
# 30  94538-6309            NaN  ...  Female Owned   Unanswered        NaN
# 31  94010-4214     02/19/2021  ...  Female Owned  Non-Veteran        NaN
# 32  94133-3905     03/18/2021  ...    Unanswered   Unanswered        NaN
# 33       94014     03/18/2021  ...    Male Owned  Non-Veteran        NaN
# 34  94117-2914            NaN  ...    Male Owned  Non-Veteran          Y
# 35  94582-5391            NaN  ...    Male Owned  Non-Veteran        NaN
# 36  94087-1939            NaN  ...  Female Owned  Non-Veteran        NaN
# 37  94401-4280     04/16/2021  ...    Male Owned  Non-Veteran        NaN
# 38  94040-2399            NaN  ...    Male Owned  Non-Veteran        NaN
# 39       94104            NaN  ...    Male Owned      Veteran        NaN
# 40       94087            NaN  ...    Male Owned  Non-Veteran        NaN
# 41       94087            NaN  ...    Male Owned  Non-Veteran        NaN
# 42  94705-2211            NaN  ...    Male Owned  Non-Veteran        NaN
# 43  94518-3615            NaN  ...    Male Owned  Non-Veteran        NaN
# 44  94301-1704     04/04/2021  ...    Male Owned  Non-Veteran        NaN
# 45       94022            NaN  ...    Male Owned  Non-Veteran        NaN
# 46  94566-7032            NaN  ...    Male Owned   Unanswered        NaN
# 47  94931-6202            NaN  ...    Male Owned  Non-Veteran        NaN
# 48  94111-3628            NaN  ...  Female Owned  Non-Veteran        NaN
# 49  95118-2009            NaN  ...    Male Owned   Unanswered        NaN
#
#     zip_code_5  Minority  YearApproved   NAICS_6  \
# 0      94027.0       Yes          2021  722511.0
# 1      94596.0       Yes          2021  722511.0
# 2      94523.0       Yes          2021  722511.0
# 3      94124.0       Yes          2021  541820.0
# 4      95405.0       Yes          2021  722511.0
# 5      94534.0       Yes          2020  484121.0
# 6      94122.0       Yes          2020  236115.0
# 7      94158.0       Yes          2021  722513.0
# 8      94544.0       Yes          2021  722511.0
# 9      94103.0       Yes          2021  721310.0
# 10     95037.0       Yes          2021  722511.0
# 11     94577.0       Yes          2021  424490.0
# 12     94538.0       Yes          2021  334118.0
# 13     94112.0       Yes          2020  722511.0
# 14     94028.0       Yes          2021  722513.0
# 15     94530.0       Yes          2020  621320.0
# 16     94107.0       Yes          2020  523930.0
# 17     94901.0       Yes          2021  811121.0
# 18     94901.0       Yes          2020  811412.0
# 19     94568.0       Yes          2021  312111.0
# 20     94117.0       Yes          2021  721310.0
# 21     94538.0       Yes          2020  335931.0
# 22     94550.0       Yes          2020  999990.0
# 23     94010.0       Yes          2021  238320.0
# 24     94618.0       Yes          2021  722511.0
# 25     94531.0       Yes          2020  722511.0
# 26     94080.0       Yes          2020  722511.0
# 27     94121.0       Yes          2021  722511.0
# 28     94518.0       Yes          2021  236115.0
# 29     94089.0       Yes          2020  541713.0
# 30     94538.0       Yes          2021  811121.0
# 31     94010.0       Yes          2021  722511.0
# 32     94133.0       Yes          2021  236118.0
# 33     94014.0       Yes          2020  621210.0
# 34     94117.0       Yes          2021  611710.0
# 35     94582.0       Yes          2021  511210.0
# 36     94087.0       Yes          2021  621399.0
# 37     94401.0       Yes          2020  541512.0
# 38     94040.0       Yes          2021  541519.0
# 39     94104.0       Yes          2020  713940.0
# 40     94087.0       Yes          2021  811111.0
# 41     94087.0       Yes          2020  811111.0
# 42     94705.0       Yes          2021  541511.0
# 43     94518.0       Yes          2021  722511.0
# 44     94301.0       Yes          2021  722513.0
# 45     94022.0       Yes          2020  621210.0
# 46     94566.0       Yes          2021  541110.0
# 47     94931.0       Yes          2020  722511.0
# 48     94111.0       Yes          2020  813920.0
# 49     95118.0       Yes          2021  611110.0
#
#                                              LongName  \
# 0                           Full-Service Restaurants
# 1                           Full-Service Restaurants
# 2                           Full-Service Restaurants
# 3                           Public Relations Agencies
# 4                           Full-Service Restaurants
# 5   General Freight Trucking, Long-Distance, Truck...
# 6   New Single-Family Housing Construction (except...
# 7                        Limited-Service Restaurants
# 8                           Full-Service Restaurants
# 9   Rooming and Boarding Houses, Dormitories, and ...
# 10                          Full-Service Restaurants
# 11  Other Grocery and Related Products Merchant Wh...
# 12  Computer Terminal and Other Computer Periphera...
# 13                          Full-Service Restaurants
# 14                       Limited-Service Restaurants
# 15                            Offices of Optometrists
# 16                                 Investment Advice
# 17  Automotive Body, Paint, and Interior Repair an...
# 18                  Appliance Repair and Maintenance
# 19                          Soft Drink Manufacturing
# 20  Rooming and Boarding Houses, Dormitories, and ...
# 21      Current-Carrying Wiring Device Manufacturing
# 22                                                NaN
# 23             Painting and Wall Covering Contractors
# 24                          Full-Service Restaurants
# 25                          Full-Service Restaurants
# 26                          Full-Service Restaurants
# 27                          Full-Service Restaurants
# 28  New Single-Family Housing Construction (except...
# 29        Research and Development in Nanotechnology
# 30  Automotive Body, Paint, and Interior Repair an...
# 31                          Full-Service Restaurants
# 32                            Residential Remodelers
# 33                               Offices of Dentists
# 34                       Educational Support Services
# 35                                Software Publishers
# 36  Offices of All Other Miscellaneous Health Prac...
# 37                  Computer Systems Design Services
# 38                    Other Computer Related Services
# 39           Fitness and Recreational Sports Centers
# 40                         General Automotive Repair
# 41                         General Automotive Repair
# 42              Custom Computer Programming Services
# 43                          Full-Service Restaurants
# 44                       Limited-Service Restaurants
# 45                               Offices of Dentists
# 46                                 Offices of Lawyers
# 47                          Full-Service Restaurants
# 48                        Professional Organizations
# 49                  Elementary and Secondary Schools
#
#                                     IndustrySubsector NAICS_4
# 0                 Restaurants and Other Eating Places  7225.0
# 1                 Restaurants and Other Eating Places  7225.0
# 2                 Restaurants and Other Eating Places  7225.0
# 3   Advertising, Public Relations, and Related Ser...  5418.0
# 4                 Restaurants and Other Eating Places  7225.0
# 5                            General Freight Trucking  4841.0
# 6                   Residential Building Construction  2361.0
# 7                 Restaurants and Other Eating Places  7225.0
# 8                 Restaurants and Other Eating Places  7225.0
# 9   Rooming and Boarding Houses, Dormitories, and ...  7213.0
# 10                Restaurants and Other Eating Places  7225.0
# 11  Grocery and Related Product Merchant Wholesalers   4244.0
# 12    Computer and Peripheral Equipment Manufacturing  3341.0
# 13                Restaurants and Other Eating Places  7225.0
# 14                Restaurants and Other Eating Places  7225.0
# 15              Offices of Other Health Practitioners  6213.0
# 16              Other Financial Investment Activities  5239.0
# 17                  Automotive Repair and Maintenance  8111.0
# 18  Personal and Household Goods Repair and Mainte...  8114.0
# 19                             Beverage Manufacturing  3121.0
# 20  Rooming and Boarding Houses, Dormitories, and ...  7213.0
# 21  Other Electrical Equipment and Component Manuf...  3359.0
# 22                                                NaN     NaN
# 23                     Building Finishing Contractors  2383.0
# 24                Restaurants and Other Eating Places  7225.0
# 25                Restaurants and Other Eating Places  7225.0
# 26                Restaurants and Other Eating Places  7225.0
# 27                Restaurants and Other Eating Places  7225.0
# 28                  Residential Building Construction  2361.0
# 29       Scientific Research and Development Services  5417.0
# 30                  Automotive Repair and Maintenance  8111.0
# 31                Restaurants and Other Eating Places  7225.0
# 32                  Residential Building Construction  2361.0
# 33                                Offices of Dentists  6212.0
# 34                       Educational Support Services  6117.0
# 35                                Software Publishers  5112.0
# 36              Offices of Other Health Practitioners  6213.0
# 37       Computer Systems Design and Related Services  5415.0
# 38       Computer Systems Design and Related Services  5415.0
# 39          Other Amusement and Recreation Industries  7139.0
# 40                  Automotive Repair and Maintenance  8111.0
# 41                  Automotive Repair and Maintenance  8111.0
# 42       Computer Systems Design and Related Services  5415.0
# 43                Restaurants and Other Eating Places  7225.0
# 44                Restaurants and Other Eating Places  7225.0
# 45                                Offices of Dentists  6212.0
# 46                                     Legal Services  5411.0
# 47                Restaurants and Other Eating Places  7225.0
# 48  Business, Professional, Labor, Political, and ...  8139.0
# 49                   Elementary and Secondary Schools  6111.0
#
# [50 rows x 58 columns]

# %%
# All caps - matches PPP's format
display(orbis_df['Company name Latin alphabet'])
# All caps - need to standardize address (.upper() on PPP or .title() on Orbis)
display(orbis_df['Address line 1\nLatin Alphabet'])
# Out:
# 0           CALIFORNIA NURSES ASSOCIATION
# 1                    HONDA CARS OF CORONA
# 2                    SIMI MANAGEMENT CORP
# 3            ECONOMY LUMBER CO OF OAKLAND
# 4                           BROADWAY FORD
#                        ...
# 92295                             STANDBY
# 92296                          CAFE DOLCI
# 92297                          SOLO SALON
# 92298             SEVEN TREES BOTTLE SHOP
# 92299    TERIYAKI HOUSE/HOUSE OF THAI INC
# Name: Company name Latin alphabet, Length: 92300, dtype: object
# 0         2000 FRANKLIN ST
# 1            3330 BROADWAY
# 2            2825 BROADWAY
# 3              750 HIGH ST
# 4          2560 WEBSTER ST
#                ...
# 92295     935 AIRPORT BLVD
# 92296       78 IDLEWOOD CT
# 92297         6 TUNITAS LN
# 92298    2164 GREENDALE DR
# 92299      243 RAINIER AVE
# Name: Address line 1\nLatin Alphabet, Length: 92300, dtype: object

# %% [markdown]
# ## Approach 1: Clean Names and Address Col to do String match

# %% [markdown]
# ## Case Examples
#
# * Look at addresses to verify that business names correspond to the same business
# * Options: NAICS (doesn't always match), ...

# %% [markdown]
# ### 1. INC vs. INC.
#
# Orbis: INDELICATO INC <br>
# PPP: INDELICATO INC. <br>
#
# **Solution:** Strip punctuation and match on just the letters

# %%
display(orbis_df[orbis_df['Company name Latin alphabet'] == 'INDELICATO INC'])
display(ppp_df[ppp_df['BorrowerName'] == 'INDELICATO INC.'])
# Out:
#       Company name Latin alphabet Inactive Quoted Branch OwnData Woco  \
# 26791              INDELICATO INC       No     No     No      No   No
#
#       Country ISO code  NACE Rev. 2, core code (4 digits) Consolidation code  \
# 26791               US                               5610                 LF
#
#        Last avail. year  ...         Latitude         Longitude  \
# 26791            2019.0  ...  37° 46' 49.5" N  122° 28' 43.8" W
#
#              Website address NAICS 2017, core code (4 digits)  \
# 26791  www.gasparespizza.com                             7223
#
#       NAICS 2017, core code - description Size classification Type of entity  \
# 26791               Special Food Services       Small company      Corporate
#
#       Ethnic minority owned indicator (in US) Woman owned indicator (in US)  \
# 26791                                      No                            No
#
#           Study Area
# 26791  San Francisco
#
# [1 rows x 27 columns]
#     LoanNumber DateApproved  SBAOfficeCode ProcessingMethod     BorrowerName  \
# 27  6336148401   02/10/2021          912.0              PPS  INDELICATO INC.
#
#     BorrowerAddress   BorrowerCity BorrowerState BorrowerZip LoanStatusDate  \
# 27  5546 Geary Blvd  San Francisco            CA  94121-2209            NaN
#
#     ...      Gender     Veteran  NonProfit  zip_code_5  Minority  \
# 27  ...  Unanswered  Unanswered        NaN     94121.0       Yes
#
#     YearApproved   NAICS_6                   LongName  \
# 27          2021  722511.0  Full-Service Restaurants
#
#                       IndustrySubsector NAICS_4
# 27  Restaurants and Other Eating Places  7225.0
#
# [1 rows x 58 columns]

# %%
# TODO: STANDARDIZE ADDRESSES ACROSS BOTH DATA FRAME
display(orbis_df[orbis_df['Company name Latin alphabet'] == 'INDELICATO INC']['Address line 1\nLatin Alphabet'] )
display(ppp_df[ppp_df['BorrowerName'] == 'INDELICATO INC.']['BorrowerAddress'])
# Out:
# 26791    5546 GEARY BLVD
# Name: Address line 1\nLatin Alphabet, dtype: object
# 27    5546 Geary Blvd
# Name: BorrowerAddress, dtype: object

# %%
# NAICS Code doesn't match
display(orbis_df[orbis_df['Company name Latin alphabet'] == 'INDELICATO INC']['NAICS 2017, core code (4 digits)'])
# TODO: Change NAICS columns' data types to int
display(ppp_df[ppp_df['BorrowerName'] == 'INDELICATO INC.']['NAICS_4'])
# Out:
# 26791    7223
# Name: NAICS 2017, core code (4 digits), dtype: int64
# 27    7225.0
# Name: NAICS_4, dtype: float64

# %%
# Naive Solution
print('INDELICATO INC vs. INDELICATO INC.')
print('is it a match?', 'INDELICATO INC' == 'INDELICATO INC.')

# Use regex to strip punctuation (not characters or spaces)
print('after modifying, is it a match?', 'INDELICATO INC' == re.sub(r'[^\w\s]','','INDELICATO INC.'))
# Out:
# INDELICATO INC vs. INDELICATO INC.
# is it a match? False
# after modifying, is it a match? True

# %% [markdown]
# ### 2. No Company Abbrv In One Name (INC. vs. no INC.)
#
# Orbis:'RISTORANTE BUON GUSTO' <br>
# PPP: 'RISTORANTE BUON GUSTO, INC' <br>
#
# Solution: Remove all company abbreviations - using cleanco library <br>
#
# Library: https://github.com/psolin/cleanco
#
# Install library by running `pip install cleanco` in terminal

# %%
# No ', INC' like in the PPP Loan Data
display(orbis_df[orbis_df['Company name Latin alphabet'] == 'RISTORANTE BUON GUSTO'])
display(ppp_df[ppp_df['BorrowerName'] == 'RISTORANTE BUON GUSTO, INC'])
# Out:
#       Company name Latin alphabet Inactive Quoted Branch OwnData Woco  \
# 90009       RISTORANTE BUON GUSTO       No     No     No      No   No
#
#       Country ISO code  NACE Rev. 2, core code (4 digits) Consolidation code  \
# 90009               US                               4725                 LF
#
#        Last avail. year  ...         Latitude         Longitude  \
# 90009            2019.0  ...  37° 39' 17.9" N  122° 24' 33.2" W
#
#                    Website address NAICS 2017, core code (4 digits)  \
# 90009  www.ristorantebuongusto.com                             4453
#
#       NAICS 2017, core code - description   Size classification  \
# 90009       Beer, Wine, and Liquor Stores  Medium sized company
#
#       Type of entity Ethnic minority owned indicator (in US)  \
# 90009      Corporate                                      No
#
#       Woman owned indicator (in US)           Study Area
# 90009                            No  South San Francisco
#
# [1 rows x 27 columns]
#     LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 26  6685727803   06/02/2020          912.0              PPP
#
#                   BorrowerName   BorrowerAddress         BorrowerCity  \
# 26  RISTORANTE BUON GUSTO, INC  224 Grand Avenue  South San Francisco
#
#    BorrowerState BorrowerZip LoanStatusDate  ...      Gender      Veteran  \
# 26            CA       94080     04/29/2021  ...  Male Owned  Non-Veteran
#
#     NonProfit  zip_code_5  Minority  YearApproved   NAICS_6  \
# 26        NaN     94080.0       Yes          2020  722511.0
#
#                      LongName                    IndustrySubsector NAICS_4
# 26  Full-Service Restaurants   Restaurants and Other Eating Places  7225.0
#
# [1 rows x 58 columns]

# %%
# Source: https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install cleanco
# Out:
# Collecting cleanco
#   Using cached cleanco-2.1-py3-none-any.whl (11 kB)
# Installing collected packages: cleanco
# Successfully installed cleanco-2.1

# %%
# Sample
from cleanco import cleanco
bus_name = 'RISTORANTE BUON GUSTO, INC'
bus_name1 = 'INDELICATO INC.'
bus_name2 = 'INDELICATO INC'
x = cleanco(bus_name)
y = cleanco(bus_name1)
z = cleanco(bus_name1)
x.clean_name(), y.clean_name(), z.clean_name()
# Out:
# ('RISTORANTE BUON GUSTO', 'INDELICATO', 'INDELICATO')

# %%
# Clean Orbis Name Column
orbis_df['Company Name - Clean'] =orbis_df['Company name Latin alphabet'].apply(lambda x: cleanco(x).clean_name())
orbis_df.head()
# Out:
#      Company name Latin alphabet Inactive Quoted Branch OwnData Woco  \
# 0  CALIFORNIA NURSES ASSOCIATION       No     No    Yes      No   No
# 1           HONDA CARS OF CORONA       No     No     No      No   No
# 2           SIMI MANAGEMENT CORP       No     No     No      No   No
# 3   ECONOMY LUMBER CO OF OAKLAND       No     No     No      No   No
# 4                  BROADWAY FORD       No     No     No      No   No
#
#   Country ISO code  NACE Rev. 2, core code (4 digits) Consolidation code  \
# 0               US                               9412                 LF
# 1               US                               4519                 LF
# 2               US                               4519                 LF
# 3               US                               4778                 LF
# 4               US                               4519                 LF
#
#    Last avail. year  ...         Longitude              Website address  \
# 0            2019.0  ...   122° 16' 1.2" W  www.calnursesfoundation.org
# 1            2019.0  ...  122° 15' 37.2" W    www.hondacarsofcorona.com
# 2            2019.0  ...  122° 15' 48.6" W                          NaN
# 3            2019.0  ...  122° 13' 10.9" W      www.economylumberco.com
# 4            2008.0  ...  122° 15' 53.5" W       www.mybroadwayford.com
#
#   NAICS 2017, core code (4 digits)  \
# 0                             8139
# 1                             4411
# 2                             4411
# 3                             4441
# 4                             4411
#
#                  NAICS 2017, core code - description Size classification  \
# 0  Business, Professional, Labor, Political, and ...  Very large company
# 1                                 Automobile Dealers       Large company
# 2                                 Automobile Dealers       Large company
# 3             Building Material and Supplies Dealers       Large company
# 4                                 Automobile Dealers       Large company
#
#   Type of entity Ethnic minority owned indicator (in US)  \
# 0      Corporate                                      No
# 1      Corporate                                      No
# 2      Corporate                                      No
# 3      Corporate                                      No
# 4      Corporate                                      No
#
#   Woman owned indicator (in US) Study Area           Company Name - Clean
# 0                            No    Oakland  CALIFORNIA NURSES ASSOCIATION
# 1                            No    Oakland           HONDA CARS OF CORONA
# 2                            No    Oakland                SIMI MANAGEMENT
# 3                            No    Oakland   ECONOMY LUMBER CO OF OAKLAND
# 4                            No    Oakland                  BROADWAY FORD
#
# [5 rows x 28 columns]

# %%
len(orbis_df)
# Out:
# 92300

# %%
# Clean PPP Name Column
ppp_df['BorrowerName - Clean'] = ppp_df['BorrowerName'].apply(lambda x: cleanco(x).clean_name())
ppp_df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  5224738402   02/08/2021          912.0              PPS
# 1  5359188509   02/27/2021          912.0              PPS
# 2  5554978603   03/20/2021          912.0              PPS
# 3  9634738305   01/31/2021          912.0              PPS
# 4  5004708402   02/07/2021          912.0              PPS
#
#               BorrowerName  BorrowerAddress   BorrowerCity BorrowerState  \
# 0                   ICHINA     70 Valley Ct       Atherton            CA
# 1      BANZAI IZAKAYA INC.  1633 Bonanza St   Walnut Creek            CA
# 2  RANGOON SUPER STARS LLC    542 Freya Way  Pleasant Hill            CA
# 3         JBR PARTNERS INC   1333 Evans Ave  San Francisco            CA
# 4                OSAKE INC    2446 Patio Ct     Santa Rosa            CA
#
#   BorrowerZip LoanStatusDate  ... NonProfit  zip_code_5  Minority  \
# 0  94027-6472            NaN  ...       NaN     94027.0       Yes
# 1  94596-4525            NaN  ...       NaN     94596.0       Yes
# 2  94523-1712            NaN  ...       NaN     94523.0       Yes
# 3  94124-1705            NaN  ...       NaN     94124.0       Yes
# 4  95405-6737            NaN  ...       NaN     95405.0       Yes
#
#    YearApproved   NAICS_6                   LongName  \
# 0          2021  722511.0  Full-Service Restaurants
# 1          2021  722511.0  Full-Service Restaurants
# 2          2021  722511.0  Full-Service Restaurants
# 3          2021  541820.0  Public Relations Agencies
# 4          2021  722511.0  Full-Service Restaurants
#
#                                    IndustrySubsector  NAICS_4  \
# 0                Restaurants and Other Eating Places   7225.0
# 1                Restaurants and Other Eating Places   7225.0
# 2                Restaurants and Other Eating Places   7225.0
# 3  Advertising, Public Relations, and Related Ser...   5418.0
# 4                Restaurants and Other Eating Places   7225.0
#
#      Address-Clean BorrowerName - Clean
# 0     70 VALLEY CT               ICHINA
# 1  1633 BONANZA ST       BANZAI IZAKAYA
# 2    542 FREYA WAY  RANGOON SUPER STARS
# 3   1333 EVANS AVE         JBR PARTNERS
# 4    2446 PATIO CT                OSAKE
#
# [5 rows x 60 columns]

# %%
len(ppp_df)
# Out:
# 31400

# %%
# Find businesses in Orbis databases -- VOID (can't do it like this)

temp = ppp_df[ppp_df['BorrowerName - Clean'].isin(orbis_df['Company Name - Clean'])]
temp.head()
# Out:
#     LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 13  6891887904   06/16/2020          912.0              PPP
# 25  3745407103   04/12/2020          912.0              PPP
# 26  6685727803   06/02/2020          912.0              PPP
# 27  6336148401   02/10/2021          912.0              PPS
# 89  7226848403   02/11/2021          912.0              PPS
#
#                        BorrowerName     BorrowerAddress         BorrowerCity  \
# 13              LYC RESTAURANT INC.      1540 Ocean Ave        San Francisco
# 25  SAMURAI JAPANESE RESTAURANT INC  5007 Lone Tree Way              Antioch
# 26       RISTORANTE BUON GUSTO, INC    224 Grand Avenue  South San Francisco
# 27                  INDELICATO INC.     5546 Geary Blvd        San Francisco
# 89             C27 SUSHI LOUNGE INC      1497 Church St        San Francisco
#
#    BorrowerState BorrowerZip LoanStatusDate  ... NonProfit  zip_code_5  \
# 13            CA  94112-1716            NaN  ...       NaN     94112.0
# 25            CA  94531-8690     03/19/2021  ...       NaN     94531.0
# 26            CA       94080     04/29/2021  ...       NaN     94080.0
# 27            CA  94121-2209            NaN  ...       NaN     94121.0
# 89            CA  94131-2049            NaN  ...       NaN     94131.0
#
#     Minority  YearApproved   NAICS_6                   LongName  \
# 13       Yes          2020  722511.0  Full-Service Restaurants
# 25       Yes          2020  722511.0  Full-Service Restaurants
# 26       Yes          2020  722511.0  Full-Service Restaurants
# 27       Yes          2021  722511.0  Full-Service Restaurants
# 89       Yes          2021  722511.0  Full-Service Restaurants
#
#                       IndustrySubsector  NAICS_4       Address-Clean  \
# 13  Restaurants and Other Eating Places   7225.0      1540 OCEAN AVE
# 25  Restaurants and Other Eating Places   7225.0  5007 LONE TREE WAY
# 26  Restaurants and Other Eating Places   7225.0    224 GRAND AVENUE
# 27  Restaurants and Other Eating Places   7225.0     5546 GEARY BLVD
# 89  Restaurants and Other Eating Places   7225.0      1497 CHURCH ST
#
#            BorrowerName - Clean
# 13               LYC RESTAURANT
# 25  SAMURAI JAPANESE RESTAURANT
# 26        RISTORANTE BUON GUSTO
# 27                   INDELICATO
# 89             C27 SUSHI LOUNGE
#
# [5 rows x 60 columns]

# %%
# Num of matches
len(temp)
# Out:
# 1547

# %%
temp.to_csv(d+'/ppp-loan-data/out/temp.csv')

# %%
temp2 = orbis_df[orbis_df['Company Name - Clean'].isin(ppp_df['BorrowerName - Clean'])]
temp2.head()
# Out:
#     Company name Latin alphabet Inactive Quoted Branch OwnData Woco  \
# 28                   TRANSPORTS       No     No     No      No   No
# 45             OAKLAND PHARMACY       No     No     No      No   No
# 65                 NW SHELL INC       No     No     No      No   No
# 66      BEAUTY SUPPLY WAREHOUSE       No     No     No      No   No
# 156        OAKLAND PHARMACY INC       No     No     No      No   No
#
#     Country ISO code  NACE Rev. 2, core code (4 digits) Consolidation code  \
# 28                US                               4764                 LF
# 45                US                               4773                 LF
# 65                US                               4730                 LF
# 66                US                               4778                 LF
# 156               US                               4773                 LF
#
#      Last avail. year  ...         Longitude            Website address  \
# 28             2019.0  ...   122° 15' 7.8" W  www.transportsrunswim.com
# 45             2019.0  ...  122° 16' 18.7" W        www.savagesdrug.com
# 65             2019.0  ...   122° 15' 2.6" W                        NaN
# 66             2019.0  ...   122° 16' 5.5" W         www.bswbayarea.com
# 156            2019.0  ...  122° 16' 13.9" W        www.savagesdrug.com
#
#     NAICS 2017, core code (4 digits)  \
# 28                              4511
# 45                              4461
# 65                              4471
# 66                              4539
# 156                             4461
#
#                    NAICS 2017, core code - description   Size classification  \
# 28   Sporting Goods, Hobby, and Musical Instrument ...  Medium sized company
# 45                     Health and Personal Care Stores  Medium sized company
# 65                                   Gasoline Stations  Medium sized company
# 66                 Other Miscellaneous Store Retailers  Medium sized company
# 156                    Health and Personal Care Stores  Medium sized company
#
#     Type of entity Ethnic minority owned indicator (in US)  \
# 28       Corporate                                      No
# 45       Corporate                                     Yes
# 65       Corporate                                      No
# 66       Corporate                                      No
# 156      Corporate                                      No
#
#     Woman owned indicator (in US) Study Area     Company Name - Clean
# 28                             No    Oakland               TRANSPORTS
# 45                             No    Oakland         OAKLAND PHARMACY
# 65                             No    Oakland                 NW SHELL
# 66                             No    Oakland  BEAUTY SUPPLY WAREHOUSE
# 156                            No    Oakland         OAKLAND PHARMACY
#
# [5 rows x 28 columns]

# %%
len(temp2)
# Out:
# 1573

# %%
temp2.to_csv(d+'/ppp-loan-data/out/temp2.csv')

# %%
temp['BorrowerName - Clean'] == temp2['Company Name - Clean']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-674bd17939f0> in <module>
# ----> 1 temp['BorrowerName - Clean'] == temp2['Company Name - Clean']
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     519
#     520         if isinstance(other, ABCSeries) and not self._indexed_same(other):
# --> 521             raise ValueError("Can only compare identically-labeled Series objects")
#     522
#     523         lvalues = extract_array(self, extract_numpy=True)
#
# ValueError: Can only compare identically-labeled Series objects

# %%
temp3 = pd.merge(temp, temp2, how='left', left_on='BorrowerName - Clean', right_on='Company Name - Clean')

temp3.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  6891887904   06/16/2020          912.0              PPP
# 1  3745407103   04/12/2020          912.0              PPP
# 2  6685727803   06/02/2020          912.0              PPP
# 3  6336148401   02/10/2021          912.0              PPS
# 4  7226848403   02/11/2021          912.0              PPS
#
#                       BorrowerName     BorrowerAddress         BorrowerCity  \
# 0              LYC RESTAURANT INC.      1540 Ocean Ave        San Francisco
# 1  SAMURAI JAPANESE RESTAURANT INC  5007 Lone Tree Way              Antioch
# 2       RISTORANTE BUON GUSTO, INC    224 Grand Avenue  South San Francisco
# 3                  INDELICATO INC.     5546 Geary Blvd        San Francisco
# 4             C27 SUSHI LOUNGE INC      1497 Church St        San Francisco
#
#   BorrowerState BorrowerZip LoanStatusDate  ...         Longitude  \
# 0            CA  94112-1716            NaN  ...  122° 27' 32.4" W
# 1            CA  94531-8690     03/19/2021  ...   121° 57' 0.4" W
# 2            CA       94080     04/29/2021  ...  122° 24' 33.2" W
# 3            CA  94121-2209            NaN  ...  122° 28' 43.8" W
# 4            CA  94131-2049            NaN  ...  122° 25' 37.1" W
#
#                Website address  NAICS 2017, core code (4 digits)  \
# 0                          NaN                              7223
# 1                          NaN                              7223
# 2  www.ristorantebuongusto.com                              4453
# 3        www.gasparespizza.com                              7223
# 4          www.kamasushisf.com                              7224
#
#      NAICS 2017, core code - description   Size classification  \
# 0                  Special Food Services         Small company
# 1                  Special Food Services         Small company
# 2          Beer, Wine, and Liquor Stores  Medium sized company
# 3                  Special Food Services         Small company
# 4  Drinking Places (Alcoholic Beverages)         Small company
#
#    Type of entity Ethnic minority owned indicator (in US)  \
# 0       Corporate                                      No
# 1       Corporate                                      No
# 2       Corporate                                      No
# 3       Corporate                                      No
# 4       Corporate                                      No
#
#    Woman owned indicator (in US)           Study Area  \
# 0                             No        San Francisco
# 1                             No             San Jose
# 2                             No  South San Francisco
# 3                             No        San Francisco
# 4                             No        San Francisco
#
#           Company Name - Clean
# 0               LYC RESTAURANT
# 1  SAMURAI JAPANESE RESTAURANT
# 2        RISTORANTE BUON GUSTO
# 3                   INDELICATO
# 4             C27 SUSHI LOUNGE
#
# [5 rows x 88 columns]

# %%
len(temp3)
# Out:
# 2349

# %% [markdown]
# ## Approach 2: Match Addresses First - Then Clean Business Names -- VOID

# %%
# Clean Orbis Address Col

# %%
# Clean PPP Address Col
ppp_df['Address-Clean'] = ppp_df['BorrowerAddress'].str.upper()
ppp_df
# Out:
#        LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0      5224738402   02/08/2021          912.0              PPS
# 1      5359188509   02/27/2021          912.0              PPS
# 2      5554978603   03/20/2021          912.0              PPS
# 3      9634738305   01/31/2021          912.0              PPS
# 4      5004708402   02/07/2021          912.0              PPS
# ...           ...          ...            ...              ...
# 31395  8664418408   02/13/2021          912.0              PPS
# 31396  9120708506   03/12/2021          912.0              PPS
# 31397  9360078408   02/16/2021          912.0              PPS
# 31398  9403758303   01/30/2021          912.0              PPS
# 31399  2946407704   05/01/2020          912.0              PPP
#
#                    BorrowerName    BorrowerAddress   BorrowerCity  \
# 0                        ICHINA       70 Valley Ct       Atherton
# 1           BANZAI IZAKAYA INC.    1633 Bonanza St   Walnut Creek
# 2       RANGOON SUPER STARS LLC      542 Freya Way  Pleasant Hill
# 3              JBR PARTNERS INC     1333 Evans Ave  San Francisco
# 4                     OSAKE INC      2446 Patio Ct     Santa Rosa
# ...                         ...                ...            ...
# 31395   OTORRES LANDSCAPING INC  10691 La Honda Rd       Woodside
# 31396  A TOUCH OF ELEGANCE INC.      1150 Crane St     Menlo Park
# 31397           SIRI GROUP INC.     1175 Folsom St  San Francisco
# 31398                    AKINAI        2092 3rd St  San Francisco
# 31399     ART N FUN STUDIO, INC                NaN            NaN
#
#       BorrowerState BorrowerZip LoanStatusDate  ...      Veteran  NonProfit  \
# 0                CA  94027-6472            NaN  ...  Non-Veteran        NaN
# 1                CA  94596-4525            NaN  ...  Non-Veteran        NaN
# 2                CA  94523-1712            NaN  ...  Non-Veteran        NaN
# 3                CA  94124-1705            NaN  ...  Non-Veteran        NaN
# 4                CA  95405-6737            NaN  ...  Non-Veteran        NaN
# ...             ...         ...            ...  ...          ...        ...
# 31395            CA  94062-5700            NaN  ...  Non-Veteran        NaN
# 31396            CA  94025-4314            NaN  ...  Non-Veteran        NaN
# 31397            CA  94103-3930            NaN  ...  Non-Veteran        NaN
# 31398            CA  94107-3122            NaN  ...      Veteran        NaN
# 31399            CA         NaN            NaN  ...  Non-Veteran        NaN
#
#        zip_code_5  Minority  YearApproved   NAICS_6  \
# 0         94027.0       Yes          2021  722511.0
# 1         94596.0       Yes          2021  722511.0
# 2         94523.0       Yes          2021  722511.0
# 3         94124.0       Yes          2021  541820.0
# 4         95405.0       Yes          2021  722511.0
# ...           ...       ...           ...       ...
# 31395     94062.0       Yes          2021  561730.0
# 31396     94025.0       Yes          2021  812112.0
# 31397     94103.0       Yes          2021  722511.0
# 31398     94107.0       Yes          2021  722511.0
# 31399         NaN       Yes          2020  712110.0
#
#                         LongName  \
# 0      Full-Service Restaurants
# 1      Full-Service Restaurants
# 2      Full-Service Restaurants
# 3      Public Relations Agencies
# 4      Full-Service Restaurants
# ...                          ...
# 31395       Landscaping Services
# 31396             Beauty Salons
# 31397  Full-Service Restaurants
# 31398  Full-Service Restaurants
# 31399                   Museums
#
#                                        IndustrySubsector NAICS_4  \
# 0                    Restaurants and Other Eating Places  7225.0
# 1                    Restaurants and Other Eating Places  7225.0
# 2                    Restaurants and Other Eating Places  7225.0
# 3      Advertising, Public Relations, and Related Ser...  5418.0
# 4                    Restaurants and Other Eating Places  7225.0
# ...                                                  ...     ...
# 31395                Services to Buildings and Dwellings  5617.0
# 31396                            Personal Care Services   8121.0
# 31397                Restaurants and Other Eating Places  7225.0
# 31398                Restaurants and Other Eating Places  7225.0
# 31399  Museums, Historical Sites, and Similar Institu...  7121.0
#
#            Address-Clean
# 0           70 VALLEY CT
# 1        1633 BONANZA ST
# 2          542 FREYA WAY
# 3         1333 EVANS AVE
# 4          2446 PATIO CT
# ...                  ...
# 31395  10691 LA HONDA RD
# 31396      1150 CRANE ST
# 31397     1175 FOLSOM ST
# 31398        2092 3RD ST
# 31399                NaN
#
# [31400 rows x 59 columns]

# %%
ppp_df.loc[ppp_df['Address-Clean'].isin(orbis_df['Address line 1\nLatin Alphabet'])]
# Out:
#        LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 7      5147588302   01/25/2021          912.0              PPS
# 13     6891887904   06/16/2020          912.0              PPP
# 24     5785248310   01/25/2021          912.0              PPS
# 27     6336148401   02/10/2021          912.0              PPS
# 49     2199528402   02/03/2021          912.0              PPS
# ...           ...          ...            ...              ...
# 31377  5865888510   03/02/2021          912.0              PPS
# 31393  7915248504   03/08/2021          912.0              PPS
# 31397  9360078408   02/16/2021          912.0              PPS
# 31398  9403758303   01/30/2021          912.0              PPS
# 31399  2946407704   05/01/2020          912.0              PPP
#
#                   BorrowerName         BorrowerAddress   BorrowerCity  \
# 7           KVS PRODUCTION INC  601 Mission Bay Blvd N  San Francisco
# 13         LYC RESTAURANT INC.          1540 Ocean Ave  San Francisco
# 24     THE ROCKRIDGE CAFE INC.        5492 College Ave        Oakland
# 27             INDELICATO INC.         5546 Geary Blvd  San Francisco
# 49       CAMBRIAN ACADEMY INC.       4340 Almaden Expy       San Jose
# ...                        ...                     ...            ...
# 31377          WLR CORPORATION         1601 Taraval St  San Francisco
# 31393          SEVEN SALON INC        5358 College Ave        Oakland
# 31397          SIRI GROUP INC.          1175 Folsom St  San Francisco
# 31398                   AKINAI             2092 3rd St  San Francisco
# 31399    ART N FUN STUDIO, INC                     NaN            NaN
#
#       BorrowerState BorrowerZip LoanStatusDate  ...      Veteran  NonProfit  \
# 7                CA  94158-2472            NaN  ...      Veteran        NaN
# 13               CA  94112-1716            NaN  ...  Non-Veteran        NaN
# 24               CA  94618-1552            NaN  ...  Non-Veteran        NaN
# 27               CA  94121-2209            NaN  ...   Unanswered        NaN
# 49               CA  95118-2009            NaN  ...   Unanswered        NaN
# ...             ...         ...            ...  ...          ...        ...
# 31377            CA  94116-2353            NaN  ...  Non-Veteran        NaN
# 31393            CA  94618-1417            NaN  ...  Non-Veteran        NaN
# 31397            CA  94103-3930            NaN  ...  Non-Veteran        NaN
# 31398            CA  94107-3122            NaN  ...      Veteran        NaN
# 31399            CA         NaN            NaN  ...  Non-Veteran        NaN
#
#        zip_code_5  Minority  YearApproved   NAICS_6  \
# 7         94158.0       Yes          2021  722513.0
# 13        94112.0       Yes          2020  722511.0
# 24        94618.0       Yes          2021  722511.0
# 27        94121.0       Yes          2021  722511.0
# 49        95118.0       Yes          2021  611110.0
# ...           ...       ...           ...       ...
# 31377     94116.0       Yes          2021  722513.0
# 31393     94618.0       Yes          2021  812112.0
# 31397     94103.0       Yes          2021  722511.0
# 31398     94107.0       Yes          2021  722511.0
# 31399         NaN       Yes          2020  712110.0
#
#                                 LongName  \
# 7           Limited-Service Restaurants
# 13             Full-Service Restaurants
# 24             Full-Service Restaurants
# 27             Full-Service Restaurants
# 49     Elementary and Secondary Schools
# ...                                  ...
# 31377       Limited-Service Restaurants
# 31393                     Beauty Salons
# 31397          Full-Service Restaurants
# 31398          Full-Service Restaurants
# 31399                           Museums
#
#                                        IndustrySubsector NAICS_4  \
# 7                    Restaurants and Other Eating Places  7225.0
# 13                   Restaurants and Other Eating Places  7225.0
# 24                   Restaurants and Other Eating Places  7225.0
# 27                   Restaurants and Other Eating Places  7225.0
# 49                      Elementary and Secondary Schools  6111.0
# ...                                                  ...     ...
# 31377                Restaurants and Other Eating Places  7225.0
# 31393                            Personal Care Services   8121.0
# 31397                Restaurants and Other Eating Places  7225.0
# 31398                Restaurants and Other Eating Places  7225.0
# 31399  Museums, Historical Sites, and Similar Institu...  7121.0
#
#                 Address-Clean
# 7      601 MISSION BAY BLVD N
# 13             1540 OCEAN AVE
# 24           5492 COLLEGE AVE
# 27            5546 GEARY BLVD
# 49          4340 ALMADEN EXPY
# ...                       ...
# 31377         1601 TARAVAL ST
# 31393        5358 COLLEGE AVE
# 31397          1175 FOLSOM ST
# 31398             2092 3RD ST
# 31399                     NaN
#
# [3420 rows x 59 columns]

# %% [markdown]
# **Ownership Name different than Name for Business (Spark)**
#
# https://opengovus.com/san-francisco-business/1139930-03-171

# %%
ppp_df[ppp_df['BorrowerName'] == 'KVS PRODUCTION INC']
ppp_df[ppp_df['BorrowerAddress'] == '601 MISSION BAY BLVD N']

# Is a food court -- multiple businesses will be in same location
# Out:
#       LoanNumber DateApproved  SBAOfficeCode ProcessingMethod    BorrowerName  \
# 1152  5073727710   05/01/2020          912.0              PPP  KVS PRODUCTION
#
#              BorrowerAddress   BorrowerCity BorrowerState BorrowerZip  \
# 1152  601 MISSION BAY BLVD N  SAN FRANCISCO            CA  94158-2472
#
#      LoanStatusDate  ...  Veteran  NonProfit  zip_code_5  Minority  \
# 1152     04/16/2021  ...  Veteran        NaN     94158.0       Yes
#
#       YearApproved   NAICS_6                               LongName  \
# 1152          2020  512120.0  Motion Picture and Video Distribution
#
#                         IndustrySubsector NAICS_4           Address-Clean
# 1152  Motion Picture and Video Industries  5121.0  601 MISSION BAY BLVD N
#
# [1 rows x 59 columns]

# %%
orbis_df[orbis_df['Address line 1\nLatin Alphabet'] =='601 MISSION BAY BLVD N']
# Out:
#       Company name Latin alphabet Inactive Quoted Branch OwnData Woco  \
# 41975       FOOD TRUCK ARMADA LLC       No     No     No      No   No
# 45672            KAFAE COFFEE LLC       No     No     No      No   No
#
#       Country ISO code  NACE Rev. 2, core code (4 digits) Consolidation code  \
# 41975               US                               5610                 LF
# 45672               US                               5610                 LF
#
#        Last avail. year  ...         Latitude         Longitude  \
# 41975            2019.0  ...  37° 46' 15.5" N  122° 23' 28.4" W
# 45672            2018.0  ...  37° 46' 15.7" N  122° 23' 26.1" W
#
#       Website address NAICS 2017, core code (4 digits)  \
# 41975             NaN                             7223
# 45672             NaN                             7223
#
#       NAICS 2017, core code - description Size classification Type of entity  \
# 41975               Special Food Services       Small company      Corporate
# 45672               Special Food Services       Small company      Corporate
#
#       Ethnic minority owned indicator (in US) Woman owned indicator (in US)  \
# 41975                                      No                            No
# 45672                                      No                            No
#
#           Study Area
# 41975  San Francisco
# 45672  San Francisco
#
# [2 rows x 27 columns]
