# %%
import pandas as pd
import numpy as np

# %%
CPS = pd.read_csv('cps_00006.csv.gz')

# %% [markdown]
# # Categories

# %% [markdown]
# ## Race

# %%
CPS['RACE'].unique()
# Out:
# array([100, 300, 200, 803, 802, 651, 801, 652, 830, 813, 806, 810, 804,
#        805, 808, 820, 811, 809, 807, 814, 812, 816, 818, 817, 815, 819])

# %%
#Create new column called race category. Create conditions for categories and assign values to each condition
conditions = [
    (CPS['RACE'] == 100),(CPS['RACE'] == 200),(CPS['RACE'] == 300),
    (CPS['RACE'] == 651),(CPS['RACE'] == 652),(CPS['RACE'] >= 801)
    ]
values = ['White', 'Black', 'American Indian/Native','Asian', 'Hawaiian/Pacific Islander', 'Two or more races']

CPS['RACE_CAT'] = np.select(conditions, values)

CPS.head(10)
# Out:
#    YEAR  SERIAL  MONTH  HWTFINL           CPSID  ASECFLAG  HFLAG  ASECWTH  \
# 0  2010       1      3      NaN  20091200101400       1.0    NaN   485.99
# 1  2010       2      3      NaN  20091201328700       1.0    NaN   531.71
# 2  2010       3      3      NaN  20091202862200       1.0    NaN   474.40
# 3  2010       3      3      NaN  20091202862200       1.0    NaN   474.40
# 4  2010       4      3      NaN  20091201328800       1.0    NaN   486.65
# 5  2010       4      3      NaN  20091201328800       1.0    NaN   486.65
# 6  2010       5      3      NaN  20091205103500       1.0    NaN   474.40
# 7  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
# 8  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
# 9  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
#
#    STATEFIP  METRO  ...  EMPSTAT   IND  CLASSWKR  PAIDEMP1  PAIDEMP1N  \
# 0        23      1  ...       32     0         0       NaN        NaN
# ...

# %%
CPS['RACE_CAT'].unique()
# Out:
# array(['White', 'American Indian/Native', 'Black', 'Two or more races',
#        'Asian', 'Hawaiian/Pacific Islander'], dtype=object)

# %%
CPS['HISPAN'].unique()
# Out:
# array([  0, 610, 100, 200, 300, 600, 611, 400, 612, 500])

# %%
#Create new column called hispanic category. Create conditions for categories and assign values to each condition
conditions = [
    (CPS['HISPAN'] == 0),(CPS['HISPAN'] >= 100)
    ]
values = ['Not Hispanic/ Latinx', 'Hispanic/ Latinx']

CPS['HISPAN_CAT'] = np.select(conditions, values)

CPS.head(10)
# Out:
#    YEAR  SERIAL  MONTH  HWTFINL           CPSID  ASECFLAG  HFLAG  ASECWTH  \
# 0  2010       1      3      NaN  20091200101400       1.0    NaN   485.99
# 1  2010       2      3      NaN  20091201328700       1.0    NaN   531.71
# 2  2010       3      3      NaN  20091202862200       1.0    NaN   474.40
# 3  2010       3      3      NaN  20091202862200       1.0    NaN   474.40
# 4  2010       4      3      NaN  20091201328800       1.0    NaN   486.65
# 5  2010       4      3      NaN  20091201328800       1.0    NaN   486.65
# 6  2010       5      3      NaN  20091205103500       1.0    NaN   474.40
# 7  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
# 8  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
# 9  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
#
#    STATEFIP  METRO  ...   IND  CLASSWKR  PAIDEMP1  PAIDEMP1N  COVIDTELEW  \
# 0        23      1  ...     0         0       NaN        NaN         NaN
# ...

# %%
CPS['HISPAN_CAT'].unique()
# Out:
# array(['Not Hispanic/ Latinx', 'Hispanic/ Latinx'], dtype=object)

# %%
CPS[["RACE_CAT", "HISPAN_CAT"]]
# Out:
#                   RACE_CAT            HISPAN_CAT
# 0                    White  Not Hispanic/ Latinx
# 1                    White  Not Hispanic/ Latinx
# 2                    White  Not Hispanic/ Latinx
# 3                    White  Not Hispanic/ Latinx
# 4                    White  Not Hispanic/ Latinx
# ...                    ...                   ...
# 3707850              White      Hispanic/ Latinx
# 3707851  Two or more races      Hispanic/ Latinx
# 3707852              White      Hispanic/ Latinx
# 3707853              White      Hispanic/ Latinx
# 3707854              White  Not Hispanic/ Latinx
#
# [3707855 rows x 2 columns]

# %%
copy=CPS.copy()

# %%
conditions = [
    (CPS['HISPAN_CAT'] == "Hispanic/ Latinx"),
    (CPS['HISPAN_CAT'] != 'Hispanic/ Latinx')
    ]
values = ["Hispanic/ Latinx", CPS["RACE_CAT"]]
CPS['RACE2_CAT'] = np.select(conditions, values)
CPS
# Out:
#          YEAR  SERIAL  MONTH   HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 0        2010       1      3       NaN  20091200101400       1.0    NaN
# 1        2010       2      3       NaN  20091201328700       1.0    NaN
# 2        2010       3      3       NaN  20091202862200       1.0    NaN
# 3        2010       3      3       NaN  20091202862200       1.0    NaN
# 4        2010       4      3       NaN  20091201328800       1.0    NaN
# ...       ...     ...    ...       ...             ...       ...    ...
# 3707850  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707851  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707852  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707853  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707854  2021   68951      3  380.0523  20210306895100       2.0    NaN
#
#          ASECWTH  STATEFIP  METRO  ...  CLASSWKR  PAIDEMP1  PAIDEMP1N  \
# ...

# %%
CPS["RACE2_CAT"].unique()
# Out:
# array(['White', 'American Indian/Native', 'Black', 'Two or more races',
#        'Asian', 'Hispanic/ Latinx', 'Hawaiian/Pacific Islander'],
#       dtype=object)

# %%
#Create new column called Asian category. Create conditions for categories and assign values to each condition
conditions = [
    (CPS['ASIAN'] == 99.),(CPS['ASIAN'] == 30.),(CPS['ASIAN'] == 10.),
    (CPS['ASIAN'] == 70.),(CPS['ASIAN'] == 40.),(CPS['ASIAN'] == 20.),
    (CPS['ASIAN'] == 50.),(CPS['ASIAN'] == 60.),
    ]
values = ['NIU', 'Filipino', 'Asian Indian','Other Asian', 'Japanese', 'Chinese', 'Korean', 'Vietnamese']

CPS['ASIAN_CAT'] = np.select(conditions, values)

CPS.head(10)
# Out:
#    YEAR  SERIAL  MONTH  HWTFINL           CPSID  ASECFLAG  HFLAG  ASECWTH  \
# 0  2010       1      3      NaN  20091200101400       1.0    NaN   485.99
# 1  2010       2      3      NaN  20091201328700       1.0    NaN   531.71
# 2  2010       3      3      NaN  20091202862200       1.0    NaN   474.40
# 3  2010       3      3      NaN  20091202862200       1.0    NaN   474.40
# 4  2010       4      3      NaN  20091201328800       1.0    NaN   486.65
# 5  2010       4      3      NaN  20091201328800       1.0    NaN   486.65
# 6  2010       5      3      NaN  20091205103500       1.0    NaN   474.40
# 7  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
# 8  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
# 9  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
#
#    STATEFIP  METRO  ...  PAIDEMP1  PAIDEMP1N  COVIDTELEW  COVIDUNAW  \
# 0        23      1  ...       NaN        NaN         NaN        NaN
# ...

# %% [markdown]
# ## Industries

# %%
OUR_INDUSTRIES = [4770, 5170, 5180, 5190, 5275, 5370, 5381, 5391, 5470, 5480, 5490, 5580, 8690, 8680, 8990, 9070]
conditions = [
    (CPS['IND']==4770),
    (CPS['IND']==5170),
    (CPS['IND']==5180),
    (CPS['IND']==5190), 
    (CPS['IND']==5275), 
    (CPS['IND']==5370), 
    (CPS['IND']==5381), 
    (CPS['IND']==5391), 
    (CPS['IND']==5470), 
    (CPS['IND']==5480), 
    (CPS['IND']==5490), 
    (CPS['IND']==5580),
    (CPS['IND']==8690),
    (CPS['IND']==8680),
    (CPS["IND"]==8990),
    (CPS["IND"]==9070),
    ~(CPS['IND'].isin(OUR_INDUSTRIES)) 
    ]
values = ['Furniture', 
          'Clothing',
          'Shoes',
          'Jewelry_Luggage',
          'Sporting_Hobby', 
          'Bookstore', 
          'Deparment_store',
          'Other_General_Merchandise',
          'Florists',
          'Office_supplies',
          'Used_Merchandise',
          'Misc_Retail',
          'Drinking_place',
          'Restaurants',
          'Nailsalon_personalcare',
          'Laundry_service',
          "Other_notinstudy"]

CPS['IND_CAT'] = np.select(conditions, values)

# %%
CPS
# Out:
#          YEAR  SERIAL  MONTH   HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 0        2010       1      3       NaN  20091200101400       1.0    NaN
# 1        2010       2      3       NaN  20091201328700       1.0    NaN
# 2        2010       3      3       NaN  20091202862200       1.0    NaN
# 3        2010       3      3       NaN  20091202862200       1.0    NaN
# 4        2010       4      3       NaN  20091201328800       1.0    NaN
# ...       ...     ...    ...       ...             ...       ...    ...
# 3707850  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707851  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707852  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707853  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707854  2021   68951      3  380.0523  20210306895100       2.0    NaN
#
#          ASECWTH  STATEFIP  METRO  ...  PAIDEMP1N  COVIDTELEW  COVIDUNAW  \
# ...

# %% [markdown]
# ## Employment

# %%
#Create new column called Self Employed category. Create conditions for categories and assign values to each condition
conditions = [
    (CPS['CLASSWKR'] == 10.),(CPS['CLASSWKR'] == 13.),(CPS['CLASSWKR'] == 14.),
    (CPS['CLASSWKR'] == 20.),(CPS['CLASSWKR'] == 21.),(CPS['CLASSWKR'] == 22.),
    (CPS['CLASSWKR'] == 23.),(CPS['CLASSWKR'] == 24.), (CPS['CLASSWKR'] == 25.),
    (CPS['CLASSWKR'] == 26.), (CPS['CLASSWKR'] == 27.), (CPS['CLASSWKR'] == 28.), 
    (CPS['CLASSWKR'] == 29.), (CPS['CLASSWKR'] == 00.), (CPS['CLASSWKR'] == 99.),
    ]
values = ['Self_Employed', 'Self_Employed', 'Self_Employed', 
          'Not_Self_Employed', 'Not_Self_Employed', 'Not_Self_Employed', 
          'Not_Self_Employed', 'Not_Self_Employed', 'Not_Self_Employed', 
          'Not_Self_Employed', 'Not_Self_Employed', 'Not_Self_Employed', 
          'Not_Self_Employed', 'NA', 'NA']

CPS['SELFEMPLOYED_CAT'] = np.select(conditions, values)

CPS.head(10)
# Out:
#    YEAR  SERIAL  MONTH  HWTFINL           CPSID  ASECFLAG  HFLAG  ASECWTH  \
# 0  2010       1      3      NaN  20091200101400       1.0    NaN   485.99
# 1  2010       2      3      NaN  20091201328700       1.0    NaN   531.71
# 2  2010       3      3      NaN  20091202862200       1.0    NaN   474.40
# 3  2010       3      3      NaN  20091202862200       1.0    NaN   474.40
# 4  2010       4      3      NaN  20091201328800       1.0    NaN   486.65
# 5  2010       4      3      NaN  20091201328800       1.0    NaN   486.65
# 6  2010       5      3      NaN  20091205103500       1.0    NaN   474.40
# 7  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
# 8  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
# 9  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
#
#    STATEFIP  METRO  ...  COVIDTELEW  COVIDUNAW  COVIDPAID  COVIDLOOK  \
# 0        23      1  ...         NaN        NaN        NaN        NaN
# ...

# %%
# Employment counts

pd.crosstab(index=CPS['SELFEMPLOYED_CAT'], columns='count', margins=True, margins_name="Total")
# Out:
# col_0                count    Total
# SELFEMPLOYED_CAT
# NA                 1873863  1873863
# Not_Self_Employed  1644956  1644956
# Self_Employed       189036   189036
# Total              3707855  3707855

# %% [markdown]
# ## Locations

# %%
# Create new column for State

conditions = [
    (CPS['STATEFIP']==6),(CPS['STATEFIP']!=6) 
    ]
values = ['CA', "Not_CA"]

CPS['State_Cat'] = np.select(conditions, values)

CPS.head(10)
# Out:
#    YEAR  SERIAL  MONTH  HWTFINL           CPSID  ASECFLAG  HFLAG  ASECWTH  \
# 0  2010       1      3      NaN  20091200101400       1.0    NaN   485.99
# 1  2010       2      3      NaN  20091201328700       1.0    NaN   531.71
# 2  2010       3      3      NaN  20091202862200       1.0    NaN   474.40
# 3  2010       3      3      NaN  20091202862200       1.0    NaN   474.40
# 4  2010       4      3      NaN  20091201328800       1.0    NaN   486.65
# 5  2010       4      3      NaN  20091201328800       1.0    NaN   486.65
# 6  2010       5      3      NaN  20091205103500       1.0    NaN   474.40
# 7  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
# 8  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
# 9  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
#
#    STATEFIP  METRO  ...  COVIDUNAW  COVIDPAID  COVIDLOOK  RACE_CAT  \
# 0        23      1  ...        NaN        NaN        NaN     White
# ...

# %%
conditions = [
    (CPS['METAREA']==7365),(CPS['METAREA']!=7365) 
    ]
values = ['Bay_Area', "Not_Bay_Area"]

CPS['SF_OAK_FRE'] = np.select(conditions, values)

CPS.head(10)
# Out:
#    YEAR  SERIAL  MONTH  HWTFINL           CPSID  ASECFLAG  HFLAG  ASECWTH  \
# 0  2010       1      3      NaN  20091200101400       1.0    NaN   485.99
# 1  2010       2      3      NaN  20091201328700       1.0    NaN   531.71
# 2  2010       3      3      NaN  20091202862200       1.0    NaN   474.40
# 3  2010       3      3      NaN  20091202862200       1.0    NaN   474.40
# 4  2010       4      3      NaN  20091201328800       1.0    NaN   486.65
# 5  2010       4      3      NaN  20091201328800       1.0    NaN   486.65
# 6  2010       5      3      NaN  20091205103500       1.0    NaN   474.40
# 7  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
# 8  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
# 9  2010       6      3      NaN  20091200402700       1.0    NaN   267.76
#
#    STATEFIP  METRO  ...  COVIDPAID  COVIDLOOK  RACE_CAT            HISPAN_CAT  \
# ...

# %% [markdown]
# ## COVID

# %%
#Create new column called COVIDPAID category. Create conditions for categories and assign values to each condition
conditions = [
    (CPS['COVIDPAID']==99),(CPS['COVIDPAID']==2.),(CPS['COVIDPAID']==1.) 
    ]
values = ['NIU', 'Yes', 'No']

CPS['COVIDPAID_CAT'] = np.select(conditions, values)

CPS.tail(10)
# Out:
#          YEAR  SERIAL  MONTH   HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 3707845  2021   68943      3  342.9225  20201206892500       2.0    NaN
# 3707846  2021   68944      3  454.7251  20210106908900       2.0    NaN
# 3707847  2021   68946      3  376.7927  20201206892800       2.0    NaN
# 3707848  2021   68946      3  376.7927  20201206892800       2.0    NaN
# 3707849  2021   68948      3  357.3416  20200307032300       2.0    NaN
# 3707850  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707851  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707852  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707853  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707854  2021   68951      3  380.0523  20210306895100       2.0    NaN
#
#          ASECWTH  STATEFIP  METRO  ...  COVIDLOOK           RACE_CAT  \
# 3707845      NaN        56      4  ...        NaN              White
# ...

# %%
# paid for hours that they were unable to work

pd.crosstab(index=CPS['COVIDPAID_CAT'], columns='count', margins=True, margins_name="Total")
# Out:
# col_0            count    Total
# COVIDPAID_CAT
# 0              2655868  2655868
# NIU             982554   982554
# No               59519    59519
# Yes               9914     9914
# Total          3707855  3707855

# %%
#Create new column called COVIDUNAW category. Create conditions for categories and assign values to each condition
conditions = [
    (CPS['COVIDUNAW']==1.),(CPS['COVIDUNAW']==99.),(CPS['COVIDUNAW']==2.) 
    ]
values = ['No', 'NIU', 'Yes']

CPS['COVIDUNAW_CAT'] = np.select(conditions, values)

CPS.tail(10)
# Out:
#          YEAR  SERIAL  MONTH   HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 3707845  2021   68943      3  342.9225  20201206892500       2.0    NaN
# 3707846  2021   68944      3  454.7251  20210106908900       2.0    NaN
# 3707847  2021   68946      3  376.7927  20201206892800       2.0    NaN
# 3707848  2021   68946      3  376.7927  20201206892800       2.0    NaN
# 3707849  2021   68948      3  357.3416  20200307032300       2.0    NaN
# 3707850  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707851  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707852  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707853  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707854  2021   68951      3  380.0523  20210306895100       2.0    NaN
#
#          ASECWTH  STATEFIP  METRO  ...           RACE_CAT  \
# 3707845      NaN        56      4  ...              White
# ...

# %%
#Create new column called COVIDLOOK category. Create conditions for categories and assign values to each condition
conditions = [
    (CPS['COVIDLOOK']==1.),(CPS['COVIDLOOK']==99.),(CPS['COVIDLOOK']==2.) 
    ]
values = ['No', 'NIU', 'Yes']

CPS['COVIDLOOK_CAT'] = np.select(conditions, values)

CPS.tail(10)
# Out:
#          YEAR  SERIAL  MONTH   HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 3707845  2021   68943      3  342.9225  20201206892500       2.0    NaN
# 3707846  2021   68944      3  454.7251  20210106908900       2.0    NaN
# 3707847  2021   68946      3  376.7927  20201206892800       2.0    NaN
# 3707848  2021   68946      3  376.7927  20201206892800       2.0    NaN
# 3707849  2021   68948      3  357.3416  20200307032300       2.0    NaN
# 3707850  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707851  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707852  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707853  2021   68950      3  327.5283  20191207029100       2.0    NaN
# 3707854  2021   68951      3  380.0523  20210306895100       2.0    NaN
#
#          ASECWTH  STATEFIP  METRO  ...            HISPAN_CAT  \
# 3707845      NaN        56      4  ...  Not Hispanic/ Latinx
# ...

# %% [markdown]
# # Employment by Industry

# %% [markdown]
# ## 2020 - US

# %%
#Extract year 2020 

CPS_2020 = CPS[(CPS['YEAR']==2020)]
CPS_2020.tail(5)
# Out:
#          YEAR  SERIAL  MONTH   HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 3380412  2020   68927     12  438.2519  20201106884600       NaN    NaN
# 3380413  2020   68931     12  334.2817  20191207029100       NaN    NaN
# 3380414  2020   68931     12  334.2817  20191207029100       NaN    NaN
# 3380415  2020   68931     12  334.2817  20191207029100       NaN    NaN
# 3380416  2020   68931     12  334.2817  20191207029100       NaN    NaN
#
#          ASECWTH  STATEFIP  METRO  ...            HISPAN_CAT  \
# 3380412      NaN        56      4  ...  Not Hispanic/ Latinx
# 3380413      NaN        56      4  ...      Hispanic/ Latinx
# 3380414      NaN        56      4  ...      Hispanic/ Latinx
# 3380415      NaN        56      4  ...      Hispanic/ Latinx
# 3380416      NaN        56      4  ...      Hispanic/ Latinx
#
#                 RACE2_CAT  ASIAN_CAT           IND_CAT   SELFEMPLOYED_CAT  \
# 3380412             White          0  Other_notinstudy  Not_Self_Employed
# ...

# %%
CPS_2020_ASECFLAG = CPS_2020[(CPS_2020['ASECFLAG']==1.0)]
CPS_2020_ASECFLAG.head(5)
# Out:
#          YEAR  SERIAL  MONTH  HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 2288970  2020       1      3      NaN  20190302844900       1.0    NaN
# 2288971  2020       1      3      NaN  20190302844900       1.0    NaN
# 2288972  2020       2      3      NaN  20181202843500       1.0    NaN
# 2288973  2020       2      3      NaN  20181202843500       1.0    NaN
# 2288974  2020       3      3      NaN  20190202831700       1.0    NaN
#
#          ASECWTH  STATEFIP  METRO  ...            HISPAN_CAT  RACE2_CAT  \
# 2288970  1552.90        23      1  ...  Not Hispanic/ Latinx      White
# 2288971  1552.90        23      1  ...  Not Hispanic/ Latinx      White
# 2288972   990.49        23      1  ...  Not Hispanic/ Latinx      White
# 2288973   990.49        23      1  ...  Not Hispanic/ Latinx      White
# 2288974  1505.27        23      1  ...  Not Hispanic/ Latinx      White
#
#          ASIAN_CAT           IND_CAT   SELFEMPLOYED_CAT  State_Cat  \
# ...

# %%
#Employment counts 2020

pd.crosstab(index=CPS_2020_ASECFLAG['SELFEMPLOYED_CAT'], columns='count', margins=True, margins_name="Total")
# Out:
# col_0               count   Total
# SELFEMPLOYED_CAT
# NA                  80288   80288
# Not_Self_Employed   69842   69842
# Self_Employed        7829    7829
# Total              157959  157959

# %%
CPS_2020_ASECFLAG.groupby(['IND_CAT', 'SELFEMPLOYED_CAT']).agg({'SELFEMPLOYED_CAT' : 'count'})
# Out:
#                                              SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT
# Bookstore                 Not_Self_Employed                33
#                           Self_Employed                     3
# Clothing                  Not_Self_Employed               399
#                           Self_Employed                    40
# Deparment_store           Not_Self_Employed               273
# Drinking_place            Not_Self_Employed                96
#                           Self_Employed                    12
# Florists                  Not_Self_Employed                30
#                           Self_Employed                    20
# Furniture                 Not_Self_Employed               220
#                           Self_Employed                    26
# Jewelry_Luggage           Not_Self_Employed                61
#                           Self_Employed                    16
# ...

# %%
Ind_Emp_group = CPS_2020_ASECFLAG.groupby(["IND_CAT","SELFEMPLOYED_CAT"]).agg({"SELFEMPLOYED_CAT" : "count"})

# %%
# proportion within industry

Ind_Emp_group.groupby(level=[0]).apply(lambda x: 100*x/x.sum())
# Out:
#                                              SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT
# Bookstore                 Not_Self_Employed         91.666667
#                           Self_Employed              8.333333
# Clothing                  Not_Self_Employed         90.888383
#                           Self_Employed              9.111617
# Deparment_store           Not_Self_Employed        100.000000
# Drinking_place            Not_Self_Employed         88.888889
#                           Self_Employed             11.111111
# Florists                  Not_Self_Employed         60.000000
#                           Self_Employed             40.000000
# Furniture                 Not_Self_Employed         89.430894
#                           Self_Employed             10.569106
# Jewelry_Luggage           Not_Self_Employed         79.220779
#                           Self_Employed             20.779221
# ...

# %%
# percent all industries (ex: .03% of self employed ppl work in the Bookstore industry)

Ind_Emp_group.groupby(level=[1]).apply(lambda x: 100*x/x.sum())
# Out:
#                                              SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT
# Bookstore                 Not_Self_Employed          0.047250
#                           Self_Employed              0.038319
# Clothing                  Not_Self_Employed          0.571289
#                           Self_Employed              0.510921
# Deparment_store           Not_Self_Employed          0.390882
# Drinking_place            Not_Self_Employed          0.137453
#                           Self_Employed              0.153276
# Florists                  Not_Self_Employed          0.042954
#                           Self_Employed              0.255460
# Furniture                 Not_Self_Employed          0.314997
#                           Self_Employed              0.332099
# Jewelry_Luggage           Not_Self_Employed          0.087340
#                           Self_Employed              0.204368
# ...

# %% [markdown]
# ## 2020 - Race Categories - US Level

# %%
# Race counts 2020

pd.crosstab(index=CPS_2020_ASECFLAG['RACE2_CAT'], columns='count', margins=True, margins_name="Total")
# Out:
# col_0                       count   Total
# RACE2_CAT
# American Indian/Native       1877    1877
# Asian                        9987    9987
# Black                       17098   17098
# Hawaiian/Pacific Islander     626     626
# Hispanic/ Latinx            29948   29948
# Two or more races            3486    3486
# White                       94937   94937
# Total                      157959  157959

# %%
# 2020 Number self employed vs race cat

pd.crosstab(index=CPS_2020_ASECFLAG['SELFEMPLOYED_CAT'], columns=CPS_2020_ASECFLAG['RACE2_CAT'], margins=True, margins_name="Total")
# Out:
# RACE2_CAT          American Indian/Native  Asian  Black  \
# SELFEMPLOYED_CAT
# NA                                   1131   4753   9217
# Not_Self_Employed                     682   4741   7425
# Self_Employed                          64    493    456
# Total                                1877   9987  17098
#
# RACE2_CAT          Hawaiian/Pacific Islander  Hispanic/ Latinx  \
# SELFEMPLOYED_CAT
# NA                                       282             15503
# Not_Self_Employed                        320             13258
# Self_Employed                             24              1187
# Total                                    626             29948
#
# RACE2_CAT          Two or more races  White   Total
# SELFEMPLOYED_CAT
# NA                              2173  47229   80288
# Not_Self_Employed               1198  42218   69842
# Self_Employed                    115   5490    7829
# Total                           3486  94937  157959

# %%
# create df ind+emp+Race

Ind_Emp_Race_group = CPS_2020_ASECFLAG.groupby(["IND_CAT", 'SELFEMPLOYED_CAT', "RACE2_CAT"]).agg({"SELFEMPLOYED_CAT" : "count"})

# %%
# employment count by race info

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
display(Ind_Emp_Race_group)
# Out:
#                                                                        SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT  RACE2_CAT
# Bookstore                 Not_Self_Employed Asian                                     1
#                                             Black                                     1
#                                             Hispanic/ Latinx                          7
#                                             White                                    24
#                           Self_Employed     Asian                                     1
#                                             White                                     2
# Clothing                  Not_Self_Employed American Indian/Native                    2
#                                             Asian                                    42
#                                             Black                                    46
# ...

# %%
# Percentage all industries (ex: .0128% of self employed ppl in Bookstore industry identify as Asian)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.5f}'.format
display(Ind_Emp_Race_group.groupby(level=[1]).apply(lambda x: 100*x/x.sum()))
# Out:
#                                                                        SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT  RACE2_CAT
# Bookstore                 Not_Self_Employed Asian                               0.00143
#                                             Black                               0.00143
#                                             Hispanic/ Latinx                    0.01002
#                                             White                               0.03436
#                           Self_Employed     Asian                               0.01277
#                                             White                               0.02555
# Clothing                  Not_Self_Employed American Indian/Native              0.00286
#                                             Asian                               0.06014
#                                             Black                               0.06586
# ...

# %% [markdown]
# ## 2020 - Race Categories - CA Level

# %%
#Extract CA from year 2020 

CPS_2020_CA = CPS_2020_ASECFLAG[(CPS_2020_ASECFLAG['STATEFIP']==6)]
CPS_2020_CA.head(5)
# Out:
#          YEAR  SERIAL  MONTH  HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 2426726  2020   81564      3      nan  20190300960800   1.00000    nan
# 2426727  2020   81564      3      nan  20190300960800   1.00000    nan
# 2426728  2020   81564      3      nan  20190300960800   1.00000    nan
# 2426729  2020   81566      3      nan  20190200953100   1.00000    nan
# 2426730  2020   81566      3      nan  20190200953100   1.00000    nan
#
#            ASECWTH  STATEFIP  METRO  METAREA  INDIVIDCC  PERNUM  WTFINL  \
# 2426726 2260.34000         6      1     9998          0       1     nan
# 2426727 2260.34000         6      1     9998          0       2     nan
# 2426728 2260.34000         6      1     9998          0       3     nan
# 2426729 3138.52000         6      1     9998          0       1     nan
# 2426730 3138.52000         6      1     9998          0       2     nan
#
#                  CPSIDP     ASECWT  RACE    ASIAN  HISPAN  EMPSTAT   IND  \
# ...

# %%
# Race counts CA in 2020

pd.crosstab(index=CPS_2020_CA['RACE2_CAT'], columns='count', margins=True, margins_name="Total")
# Out:
# col_0                      count  Total
# RACE2_CAT
# American Indian/Native        66     66
# Asian                       2448   2448
# Black                        756    756
# Hawaiian/Pacific Islander     86     86
# Hispanic/ Latinx            6828   6828
# Two or more races            338    338
# White                       5171   5171
# Total                      15693  15693

# %%
# CA in 2020 - Number self employed vs race cat

pd.crosstab(index=CPS_2020_CA['SELFEMPLOYED_CAT'], columns=CPS_2020_ASECFLAG['RACE2_CAT'], margins=True, margins_name="Total")
# Out:
# RACE2_CAT          American Indian/Native  Asian  Black  \
# SELFEMPLOYED_CAT
# NA                                     47   1213    409
# Not_Self_Employed                      16   1110    319
# Self_Employed                           3    125     28
# Total                                  66   2448    756
#
# RACE2_CAT          Hawaiian/Pacific Islander  Hispanic/ Latinx  \
# SELFEMPLOYED_CAT
# NA                                        34              3501
# Not_Self_Employed                         48              3070
# Self_Employed                              4               257
# Total                                     86              6828
#
# RACE2_CAT          Two or more races  White  Total
# SELFEMPLOYED_CAT
# NA                               212   2513   7929
# Not_Self_Employed                111   2277   6951
# Self_Employed                     15    381    813
# Total                            338   5171  15693

# %%
# create df ind+emp+race_CA

Ind_Emp_Race_groupCA = CPS_2020_CA.groupby(["IND_CAT", 'SELFEMPLOYED_CAT', "RACE2_CAT"]).agg({"SELFEMPLOYED_CAT" : "count"})

# %%
# employment count by race info

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
display(Ind_Emp_Race_groupCA)
# Out:
#                                                                        SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT  RACE2_CAT
# Bookstore                 Not_Self_Employed Asian                                     1
#                                             Hispanic/ Latinx                          3
#                                             White                                     1
#                           Self_Employed     White                                     1
# Clothing                  Not_Self_Employed Asian                                    11
#                                             Hispanic/ Latinx                         21
#                                             Two or more races                         1
#                                             White                                    20
#                           Self_Employed     Asian                                     1
# ...

# %%
# Percentage all industries (ex: In CA, .14% of self employed ppl in Bookstore industry identify as White)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.5f}'.format
display(Ind_Emp_Race_groupCA.groupby(level=[1]).apply(lambda x: 100*x/x.sum()))
# Out:
#                                                                        SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT  RACE2_CAT
# Bookstore                 Not_Self_Employed Asian                               0.01439
#                                             Hispanic/ Latinx                    0.04316
#                                             White                               0.01439
#                           Self_Employed     White                               0.12300
# Clothing                  Not_Self_Employed Asian                               0.15825
#                                             Hispanic/ Latinx                    0.30211
#                                             Two or more races                   0.01439
#                                             White                               0.28773
#                           Self_Employed     Asian                               0.12300
# ...

# %% [markdown]
# ## 2020 - Minority Categories - US Level

# %% [markdown]
# ### Study Groups

# %%
#Create new column for study minority groups (Black, Asian, Hispanic/Latinx)


conditions = [
    (CPS_2020_ASECFLAG['RACE2_CAT'] == "Black"),
    (CPS_2020_ASECFLAG['RACE2_CAT'] == "Asian"),
    (CPS_2020_ASECFLAG['RACE2_CAT'] == "Hispanic/ Latinx"),
    (CPS_2020_ASECFLAG['RACE2_CAT'] == "White"),
    (CPS_2020_ASECFLAG['RACE2_CAT'] == "American Indian/Native"),
    (CPS_2020_ASECFLAG['RACE2_CAT'] == 'Hawaiian/Pacific Islander'),
        (CPS_2020_ASECFLAG['RACE2_CAT'] == "Two or more races"),
    ]

values = [ 'Study Minority Group', 'Study Minority Group', 'Study Minority Group',
          'Not in Study', 'Not in Study', 'Not in Study', 'Not in Study' ]

CPS_2020_ASECFLAG['STUDYGROUPS_CAT'] = np.select(conditions, values)
CPS_2020_ASECFLAG.head(10)
# Out:
# <ipython-input-42-e03f894944c4>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CPS_2020_ASECFLAG['STUDYGROUPS_CAT'] = np.select(conditions, values)
#          YEAR  SERIAL  MONTH  HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 2288970  2020       1      3      nan  20190302844900   1.00000    nan
# 2288971  2020       1      3      nan  20190302844900   1.00000    nan
# 2288972  2020       2      3      nan  20181202843500   1.00000    nan
# 2288973  2020       2      3      nan  20181202843500   1.00000    nan
# 2288974  2020       3      3      nan  20190202831700   1.00000    nan
# 2288975  2020       4      3      nan  20190302822300   1.00000    nan
# 2288976  2020       4      3      nan  20190302822300   1.00000    nan
# ...

# %%
# Race counts by Minority grouping
pd.crosstab(index=CPS_2020_ASECFLAG['STUDYGROUPS_CAT'], columns='count', margins=True, margins_name="Total")
# Out:
# col_0                  count   Total
# STUDYGROUPS_CAT
# Not in Study          100926  100926
# Study Minority Group   57033   57033
# Total                 157959  157959

# %%
# 2020 Number self employed vs race cat

pd.crosstab(index=CPS_2020_ASECFLAG['SELFEMPLOYED_CAT'], columns=CPS_2020_ASECFLAG['STUDYGROUPS_CAT'], margins=True, margins_name="Total")
# Out:
# STUDYGROUPS_CAT    Not in Study  Study Minority Group   Total
# SELFEMPLOYED_CAT
# NA                        50815                 29473   80288
# Not_Self_Employed         44418                 25424   69842
# Self_Employed              5693                  2136    7829
# Total                    100926                 57033  157959

# %%
# create df ind+emp+Race

Ind_Emp_Minority_group = CPS_2020_ASECFLAG.groupby(["IND_CAT", 'SELFEMPLOYED_CAT', "STUDYGROUPS_CAT"]).agg({"SELFEMPLOYED_CAT" : "count"})

# %%
# employment count by race info

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
display(Ind_Emp_Minority_group)
# Out:
#                                                                   SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT  STUDYGROUPS_CAT
# Bookstore                 Not_Self_Employed Not in Study                        24
#                                             Study Minority Group                 9
#                           Self_Employed     Not in Study                         2
#                                             Study Minority Group                 1
# Clothing                  Not_Self_Employed Not in Study                       203
#                                             Study Minority Group               196
#                           Self_Employed     Not in Study                        20
#                                             Study Minority Group                20
# Deparment_store           Not_Self_Employed Not in Study                       155
#                                             Study Minority Group               118
# ...

# %%
# Percentage all industries (ex: .0128% of self employed ppl in Bookstore industry identify as being either Asian, Black, or Hispanic/Latinx)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.5f}'.format
display(Ind_Emp_Minority_group.groupby(level=[1]).apply(lambda x: 100*x/x.sum()))
# Out:
#                                                                   SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT  STUDYGROUPS_CAT
# Bookstore                 Not_Self_Employed Not in Study                   0.03436
#                                             Study Minority Group           0.01289
#                           Self_Employed     Not in Study                   0.02555
#                                             Study Minority Group           0.01277
# Clothing                  Not_Self_Employed Not in Study                   0.29066
#                                             Study Minority Group           0.28063
#                           Self_Employed     Not in Study                   0.25546
#                                             Study Minority Group           0.25546
# Deparment_store           Not_Self_Employed Not in Study                   0.22193
#                                             Study Minority Group           0.16895
# ...

# %% [markdown]
# ### All Minority Groups

# %%
#Create new column for all minority groups 
#Black, Asian, Hispanic/Latinx, American Indian/Native, Hawaiian/Pacific Islander, Two or more Races"


conditions = [
    (CPS_2020_ASECFLAG['RACE2_CAT'] == "Black"),
    (CPS_2020_ASECFLAG['RACE2_CAT'] == "Asian"),
    (CPS_2020_ASECFLAG['RACE2_CAT'] == "Hispanic/ Latinx"),
    (CPS_2020_ASECFLAG['RACE2_CAT'] == "American Indian/Native"),
    (CPS_2020_ASECFLAG['RACE2_CAT'] == 'Hawaiian/Pacific Islander'),
    (CPS_2020_ASECFLAG['RACE2_CAT'] == "Two or more races"),
    (CPS_2020_ASECFLAG['RACE2_CAT'] == "White"),
    ]

values = [ 'Minority Group', 'Minority Group', 'Minority Group',
          'Minority Group', 'Minority Group', 'Minority Group', 'White' ]

CPS_2020_ASECFLAG['MINORITYGROUPS_CAT'] = np.select(conditions, values)
CPS_2020_ASECFLAG.head(10)
# Out:
# <ipython-input-48-40d346ddfcf5>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CPS_2020_ASECFLAG['MINORITYGROUPS_CAT'] = np.select(conditions, values)
#          YEAR  SERIAL  MONTH  HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 2288970  2020       1      3      nan  20190302844900   1.00000    nan
# 2288971  2020       1      3      nan  20190302844900   1.00000    nan
# 2288972  2020       2      3      nan  20181202843500   1.00000    nan
# 2288973  2020       2      3      nan  20181202843500   1.00000    nan
# 2288974  2020       3      3      nan  20190202831700   1.00000    nan
# 2288975  2020       4      3      nan  20190302822300   1.00000    nan
# 2288976  2020       4      3      nan  20190302822300   1.00000    nan
# ...

# %%
# Race counts by Minority grouping

pd.crosstab(index=CPS_2020_ASECFLAG['MINORITYGROUPS_CAT'], columns='count', margins=True, margins_name="Total")
# Out:
# col_0                count   Total
# MINORITYGROUPS_CAT
# Minority Group       63022   63022
# White                94937   94937
# Total               157959  157959

# %%
# 2020 Number self employed vs race cat

pd.crosstab(index=CPS_2020_ASECFLAG['SELFEMPLOYED_CAT'], columns=CPS_2020_ASECFLAG['MINORITYGROUPS_CAT'], margins=True, margins_name="Total")
# Out:
# MINORITYGROUPS_CAT  Minority Group  White   Total
# SELFEMPLOYED_CAT
# NA                           33059  47229   80288
# Not_Self_Employed            27624  42218   69842
# Self_Employed                 2339   5490    7829
# Total                        63022  94937  157959

# %%
# create df ind+emp+Race

Ind_Emp_AllMinority_group = CPS_2020_ASECFLAG.groupby(["IND_CAT", 'SELFEMPLOYED_CAT', "MINORITYGROUPS_CAT"]).agg({"SELFEMPLOYED_CAT" : "count"})

# %%
# employment count by race info

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
display(Ind_Emp_AllMinority_group)
# Out:
#                                                                 SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT  MINORITYGROUPS_CAT
# Bookstore                 Not_Self_Employed Minority Group                     9
#                                             White                             24
#                           Self_Employed     Minority Group                     1
#                                             White                              2
# Clothing                  Not_Self_Employed Minority Group                   209
#                                             White                            190
#                           Self_Employed     Minority Group                    22
#                                             White                             18
# Deparment_store           Not_Self_Employed Minority Group                   127
#                                             White                            146
# ...

# %%
# Percentage all industries (ex: .0128% of self employed ppl in Bookstore industry identify as being a minority)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.5f}'.format
display(Ind_Emp_AllMinority_group.groupby(level=[1]).apply(lambda x: 100*x/x.sum()))
# Out:
#                                                                 SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT  MINORITYGROUPS_CAT
# Bookstore                 Not_Self_Employed Minority Group               0.01289
#                                             White                        0.03436
#                           Self_Employed     Minority Group               0.01277
#                                             White                        0.02555
# Clothing                  Not_Self_Employed Minority Group               0.29925
#                                             White                        0.27204
#                           Self_Employed     Minority Group               0.28101
#                                             White                        0.22991
# Deparment_store           Not_Self_Employed Minority Group               0.18184
#                                             White                        0.20904
# ...

# %% [markdown]
# ## 2020 - Minority Categories - CA Level

# %% [markdown]
# ### Study Groups

# %%
#Extract CA from year 2020 

CPS_2020_CA = CPS_2020_ASECFLAG[(CPS_2020_ASECFLAG['STATEFIP']==6)]
CPS_2020_CA.head(5)
# Out:
#          YEAR  SERIAL  MONTH  HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 2426726  2020   81564      3      nan  20190300960800   1.00000    nan
# 2426727  2020   81564      3      nan  20190300960800   1.00000    nan
# 2426728  2020   81564      3      nan  20190300960800   1.00000    nan
# 2426729  2020   81566      3      nan  20190200953100   1.00000    nan
# 2426730  2020   81566      3      nan  20190200953100   1.00000    nan
#
#            ASECWTH  STATEFIP  METRO  METAREA  INDIVIDCC  PERNUM  WTFINL  \
# 2426726 2260.34000         6      1     9998          0       1     nan
# 2426727 2260.34000         6      1     9998          0       2     nan
# 2426728 2260.34000         6      1     9998          0       3     nan
# 2426729 3138.52000         6      1     9998          0       1     nan
# 2426730 3138.52000         6      1     9998          0       2     nan
#
#                  CPSIDP     ASECWT  RACE    ASIAN  HISPAN  EMPSTAT   IND  \
# ...

# %%
# Race counts by Minority grouping
pd.crosstab(index=CPS_2020_CA['STUDYGROUPS_CAT'], columns='count', margins=True, margins_name="Total")
# Out:
# col_0                 count  Total
# STUDYGROUPS_CAT
# Not in Study           5661   5661
# Study Minority Group  10032  10032
# Total                 15693  15693

# %%
# 2020 Number self employed vs race cat

pd.crosstab(index=CPS_2020_CA['SELFEMPLOYED_CAT'], columns=CPS_2020_CA['STUDYGROUPS_CAT'], margins=True, margins_name="Total")
# Out:
# STUDYGROUPS_CAT    Not in Study  Study Minority Group  Total
# SELFEMPLOYED_CAT
# NA                         2806                  5123   7929
# Not_Self_Employed          2452                  4499   6951
# Self_Employed               403                   410    813
# Total                      5661                 10032  15693

# %%
# create df ind+emp+Race

Ind_Emp_Minority_groupCA = CPS_2020_CA.groupby(["IND_CAT", 'SELFEMPLOYED_CAT', "STUDYGROUPS_CAT"]).agg({"SELFEMPLOYED_CAT" : "count"})

# %%
# employment count by race info

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
display(Ind_Emp_Minority_groupCA)
# Out:
#                                                                   SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT  STUDYGROUPS_CAT
# Bookstore                 Not_Self_Employed Not in Study                         1
#                                             Study Minority Group                 4
#                           Self_Employed     Not in Study                         1
# Clothing                  Not_Self_Employed Not in Study                        21
#                                             Study Minority Group                32
#                           Self_Employed     Study Minority Group                 2
# Deparment_store           Not_Self_Employed Not in Study                         5
#                                             Study Minority Group                14
# Drinking_place            Not_Self_Employed Not in Study                         1
#                                             Study Minority Group                 5
# ...

# %%
# Percentage all industries (ex: In CA, .246% of self employed ppl in Clothinh industry identify as being either Asian, Black, or Hispanic/Latinx)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.5f}'.format
display(Ind_Emp_Minority_groupCA.groupby(level=[1]).apply(lambda x: 100*x/x.sum()))
# Out:
#                                                                   SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT  STUDYGROUPS_CAT
# Bookstore                 Not_Self_Employed Not in Study                   0.01439
#                                             Study Minority Group           0.05755
#                           Self_Employed     Not in Study                   0.12300
# Clothing                  Not_Self_Employed Not in Study                   0.30211
#                                             Study Minority Group           0.46037
#                           Self_Employed     Study Minority Group           0.24600
# Deparment_store           Not_Self_Employed Not in Study                   0.07193
#                                             Study Minority Group           0.20141
# Drinking_place            Not_Self_Employed Not in Study                   0.01439
#                                             Study Minority Group           0.07193
# ...

# %% [markdown]
# ### All Minority Groups

# %%
# Race counts by Minority grouping

pd.crosstab(index=CPS_2020_CA['MINORITYGROUPS_CAT'], columns='count', margins=True, margins_name="Total")
# Out:
# col_0               count  Total
# MINORITYGROUPS_CAT
# Minority Group      10522  10522
# White                5171   5171
# Total               15693  15693

# %%
# 2020 Number self employed vs race cat

pd.crosstab(index=CPS_2020_CA['SELFEMPLOYED_CAT'], columns=CPS_2020_ASECFLAG['MINORITYGROUPS_CAT'], margins=True, margins_name="Total")
# Out:
# MINORITYGROUPS_CAT  Minority Group  White  Total
# SELFEMPLOYED_CAT
# NA                            5416   2513   7929
# Not_Self_Employed             4674   2277   6951
# Self_Employed                  432    381    813
# Total                        10522   5171  15693

# %%
# create df ind+emp+Race

Ind_Emp_AllMinority_groupCA = CPS_2020_CA.groupby(["IND_CAT", 'SELFEMPLOYED_CAT', "MINORITYGROUPS_CAT"]).agg({"SELFEMPLOYED_CAT" : "count"})

# %%
# employment count by race info

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
display(Ind_Emp_AllMinority_groupCA)
# Out:
#                                                                 SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT  MINORITYGROUPS_CAT
# Bookstore                 Not_Self_Employed Minority Group                     4
#                                             White                              1
#                           Self_Employed     White                              1
# Clothing                  Not_Self_Employed Minority Group                    33
#                                             White                             20
#                           Self_Employed     Minority Group                     2
# Deparment_store           Not_Self_Employed Minority Group                    14
#                                             White                              5
# Drinking_place            Not_Self_Employed Minority Group                     5
#                                             White                              1
# ...

# %%
# Percentage all industries (ex: In CA, .246% of self employed ppl in Clothinh industry identify as being either Asian, Black, or Hispanic/Latinx)


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.5f}'.format
display(Ind_Emp_AllMinority_groupCA.groupby(level=[1]).apply(lambda x: 100*x/x.sum()))
# Out:
#                                                                 SELFEMPLOYED_CAT
# IND_CAT                   SELFEMPLOYED_CAT  MINORITYGROUPS_CAT
# Bookstore                 Not_Self_Employed Minority Group               0.05755
#                                             White                        0.01439
#                           Self_Employed     White                        0.12300
# Clothing                  Not_Self_Employed Minority Group               0.47475
#                                             White                        0.28773
#                           Self_Employed     Minority Group               0.24600
# Deparment_store           Not_Self_Employed Minority Group               0.20141
#                                             White                        0.07193
# Drinking_place            Not_Self_Employed Minority Group               0.07193
#                                             White                        0.01439
# ...

# %% [markdown]
# # Minority Ownership - US Level

# %%
#Extract self-employed from year 2020 

CPS_2020_selfemp = CPS_2020_ASECFLAG[(CPS_2020_ASECFLAG['SELFEMPLOYED_CAT'] == 'Self_Employed')] 
CPS_2020_selfemp.head(10)
# Out:
#          YEAR  SERIAL  MONTH  HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 2288992  2020      15      3      nan  20191202798200   1.00000    nan
# 2289042  2020      68      3      nan               0   1.00000    nan
# 2289058  2020      78      3      nan  20191202780200   1.00000    nan
# 2289059  2020      78      3      nan  20191202780200   1.00000    nan
# 2289073  2020     101      3      nan  20190202841500   1.00000    nan
# 2289076  2020     101      3      nan  20190202841500   1.00000    nan
# 2289077  2020     101      3      nan  20190202841500   1.00000    nan
# 2289079  2020     102      3      nan  20200102807800   1.00000    nan
# 2289085  2020     103      3      nan  20181202833700   1.00000    nan
# 2289115  2020     133      3      nan               0   1.00000    nan
#
#            ASECWTH  STATEFIP  METRO  METAREA  INDIVIDCC  PERNUM  WTFINL  \
# 2288992 1283.28000        23      1     9998          0       1     nan
# ...

# %%
# 2020 Number Minority owned vs Industry

pd.crosstab(index=CPS_2020_selfemp['IND_CAT'], columns=CPS_2020_selfemp['MINORITYGROUPS_CAT'], margins=True, margins_name="Total")
# Out:
# MINORITYGROUPS_CAT         Minority Group  White  Total
# IND_CAT
# Bookstore                               1      2      3
# Clothing                               22     18     40
# Drinking_place                          2     10     12
# Florists                                6     14     20
# Furniture                               4     22     26
# Jewelry_Luggage                         3     13     16
# Laundry_service                        18      4     22
# Misc_Retail                            13     43     56
# Nailsalon_personalcare                 44     53     97
# Office_supplies                         0      2      2
# Other_General_Merchandise               1      2      3
# Other_notinstudy                     2111   5125   7236
# Restaurants                            99    133    232
# Shoes                                   1      0      1
# Sporting_Hobby                          6     26     32
# Used_Merchandise                        8     23     31
# ...

# %%
# create df minority ownership x Indus

Ind_Minority_group = CPS_2020_selfemp.groupby(["IND_CAT", "MINORITYGROUPS_CAT"]).agg({"MINORITYGROUPS_CAT" : "count"})

# %%
# Ownership % by racial category (ex: 33% of bookstores are minority owned)


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.5f}'.format
display(Ind_Minority_group.groupby(level=[0]).apply(lambda x: 100*x/x.sum()))
# Out:
#                                               MINORITYGROUPS_CAT
# IND_CAT                   MINORITYGROUPS_CAT
# Bookstore                 Minority Group                33.33333
#                           White                         66.66667
# Clothing                  Minority Group                55.00000
#                           White                         45.00000
# Drinking_place            Minority Group                16.66667
#                           White                         83.33333
# Florists                  Minority Group                30.00000
#                           White                         70.00000
# Furniture                 Minority Group                15.38462
#                           White                         84.61538
# Jewelry_Luggage           Minority Group                18.75000
#                           White                         81.25000
# Laundry_service           Minority Group                81.81818
# ...

# %% [markdown]
# # Minority Ownership - CA Level

# %%
#Extract CA from 2020 self-employed

CPS_2020_selfempCA = CPS_2020_selfemp[(CPS_2020_selfemp['State_Cat'] == 'CA')] 
CPS_2020_selfempCA.head(10)
# Out:
#          YEAR  SERIAL  MONTH  HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 2426740  2020   81578      3      nan  20190200962600   1.00000    nan
# 2426746  2020   81582      3      nan  20200100946000   1.00000    nan
# 2426757  2020   81591      3      nan  20181200959200   1.00000    nan
# 2426764  2020   81596      3      nan  20200100946100   1.00000    nan
# 2426771  2020   81598      3      nan  20181200947800   1.00000    nan
# 2426772  2020   81598      3      nan  20181200947800   1.00000    nan
# 2426811  2020   81629      3      nan  20190300959100   1.00000    nan
# 2426823  2020   81638      3      nan  20181200962800   1.00000    nan
# 2426824  2020   81638      3      nan  20181200962800   1.00000    nan
# 2426825  2020   81639      3      nan  20200200960300   1.00000    nan
#
#            ASECWTH  STATEFIP  METRO  METAREA  INDIVIDCC  PERNUM  WTFINL  \
# 2426740 2231.45000         6      1     9998          0       1     nan
# ...

# %%
# 2020 Number Minority owned vs Industry in CA

pd.crosstab(index=CPS_2020_selfempCA['IND_CAT'], columns=CPS_2020_selfempCA['MINORITYGROUPS_CAT'], margins=True, margins_name="Total")
# Out:
# MINORITYGROUPS_CAT      Minority Group  White  Total
# IND_CAT
# Bookstore                            0      1      1
# Clothing                             2      0      2
# Drinking_place                       1      0      1
# Florists                             0      2      2
# Furniture                            1      2      3
# Jewelry_Luggage                      0      1      1
# Laundry_service                      6      0      6
# Misc_Retail                          4      8     12
# Nailsalon_personalcare               9      2     11
# Other_notinstudy                   388    358    746
# Restaurants                         17      5     22
# Shoes                                1      0      1
# Sporting_Hobby                       1      0      1
# Used_Merchandise                     2      2      4
# Total                              432    381    813

# %%
# create df minority ownership x Indus

Ind_Minority_groupCA = CPS_2020_selfempCA.groupby(["IND_CAT", "MINORITYGROUPS_CAT"]).agg({"MINORITYGROUPS_CAT" : "count"})

# %%
# Ownership % by racial category (ex: in CA, 100% of self-employed respondents worked in Bookstore industry)


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.5f}'.format
display(Ind_Minority_groupCA.groupby(level=[0]).apply(lambda x: 100*x/x.sum()))
# Out:
#                                            MINORITYGROUPS_CAT
# IND_CAT                MINORITYGROUPS_CAT
# Bookstore              White                        100.00000
# Clothing               Minority Group               100.00000
# Drinking_place         Minority Group               100.00000
# Florists               White                        100.00000
# Furniture              Minority Group                33.33333
#                        White                         66.66667
# Jewelry_Luggage        White                        100.00000
# Laundry_service        Minority Group               100.00000
# Misc_Retail            Minority Group                33.33333
#                        White                         66.66667
# Nailsalon_personalcare Minority Group                81.81818
#                        White                         18.18182
# Other_notinstudy       Minority Group                52.01072
# ...
